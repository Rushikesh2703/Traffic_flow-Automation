# %%
from ultralytics import YOLO
import cv2
import tkinter as tk
from tkinter import filedialog, messagebox, simpledialog
import time
import threading
import socket
import json
from queue import Queue

# %%
# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # Automatically downloads if not present

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

class TrafficSignalController:
    def __init__(self, signal_id, neighbors=None):
        self.signal_id = signal_id
        self.current_signal_time = 10
        self.max_time = 70
        self.min_time = 10
        self.neighbor_signals = {}  # Stores neighbor congestion data
        self.congestion_level = "low"
        
        # Initialize neighbors (simulated)
        if neighbors:
            for neighbor_id in neighbors:
                self.neighbor_signals[neighbor_id] = {
                    'congestion': 'low',
                    'direction': 'outgoing',
                    'last_update': time.time()
                }

    def calculate_signal_time(self, frame_vehicle_count):
        """Adjust signal time based on vehicle count & neighbor congestion"""
        # Base calculation
        if frame_vehicle_count <= 5:
            base_time = 10
        elif 6 <= frame_vehicle_count <= 25:
            base_time = 10 + (frame_vehicle_count - 5) * 2
        else:
            base_time = 50 + (frame_vehicle_count - 25) * 0.8

        # Adjust based on neighbor congestion
        neighbor_adjustment = 0
        current_time = time.time()
        
        for neighbor_id, data in list(self.neighbor_signals.items()):
            # Remove stale entries (>5 sec old)
            if current_time - data['last_update'] > 5:
                continue
                
            if data['congestion'] == 'high' and data['direction'] == 'incoming':
                neighbor_adjustment += 5  # Increase time if neighbor is congested
            elif data['congestion'] == 'low' and data['direction'] == 'outgoing':
                neighbor_adjustment -= 2  # Decrease time if neighbor is clear

        final_time = max(self.min_time, min(base_time + neighbor_adjustment, self.max_time))
        return final_time

    def update_neighbor_status(self, neighbor_id, congestion, direction):
        """Update simulated neighbor's congestion status"""
        if neighbor_id in self.neighbor_signals:
            self.neighbor_signals[neighbor_id] = {
                'congestion': congestion,
                'direction': direction,
                'last_update': time.time()
            }
            # Print the received update
            print(f"Signal {neighbor_id} received update from Signal {self.signal_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")

    def send_congestion_update(self, congestion, direction):
        """Simulate sending congestion status to neighbors"""
        self.congestion_level = congestion
        for neighbor_id in self.neighbor_signals:
            # Print the status being sent before updating
            print(f"Signal {self.signal_id} sending to Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Simulate neighbor receiving the update
            self.update_neighbor_status(neighbor_id, congestion, direction)

class VideoProcessor:
    def __init__(self, signal_id, neighbors=None):
        self.cap = None
        self.processing = False
        self.signal_controller = TrafficSignalController(signal_id, neighbors)
        self.last_frame_details = {
            'frame_number': 0,
            'vehicle_count': 0,
            'signal_time': 10,
            'congestion_level': 'low'
        }
        self.congestion_thresholds = {'low': 10, 'medium': 25, 'high': 40}
        self.direction = 'outgoing'  # Default traffic direction

    def get_congestion_level(self, count):
        if count < self.congestion_thresholds['low']:
            return 'low'
        elif count < self.congestion_thresholds['medium']:
            return 'medium'
        else:
            return 'high'

    def process_video(self, video_source):
        self.cap = cv2.VideoCapture(video_source)
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Could not open video source!")
            return

        self.processing = True
        frame_number = 0
        last_update_time = 0

        while self.processing:
            ret, frame = self.cap.read()
            if not ret:
                break

            frame_number += 1
            results = model(frame)
            result_frame = results[0].plot()

            # Count vehicles
            vehicle_count = sum(1 for result in results for box in result.boxes 
                              if model.names[int(box.cls)] in vehicle_classes)

            congestion = self.get_congestion_level(vehicle_count)
            signal_time = self.signal_controller.calculate_signal_time(vehicle_count)

            # Update last frame details
            self.last_frame_details = {
                'frame_number': frame_number,
                'vehicle_count': vehicle_count,
                'signal_time': signal_time,
                'congestion_level': congestion
            }

            # Send congestion updates (throttled to 1 per second)
            if time.time() - last_update_time > 1:
                print(f"\n--- Frame {frame_number} Update ---")
                print(f"Current congestion at Signal {self.signal_controller.signal_id}: {congestion}")
                self.signal_controller.send_congestion_update(congestion, self.direction)
                last_update_time = time.time()

            # Display info
            self.display_info(result_frame, frame_number, vehicle_count, signal_time, congestion)
            cv2.imshow(f"Signal {self.signal_controller.signal_id}", result_frame)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                self.stop_processing()

        self.cleanup()

    def display_info(self, frame, frame_num, vehicles, signal_time, congestion):
        cv2.putText(frame, f"Signal {self.signal_controller.signal_id}", (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"Vehicles: {vehicles}", (10, 70), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Signal Time: {signal_time:.1f}s", (10, 110), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        color = (0, 0, 255) if congestion == 'high' else (0, 255, 0) if congestion == 'medium' else (255, 255, 0)
        cv2.putText(frame, f"Congestion: {congestion}", (10, 150), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        cv2.putText(frame, "Press 'q' to stop", (10, 190), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    def stop_processing(self):
        self.processing = False

    def cleanup(self):
        if self.cap:
            self.cap.release()
        cv2.destroyAllWindows()

def start_signal_system():
    root = tk.Tk()
    root.title("Traffic Signal Controller")
    root.geometry("400x250")

    def start_processing():
        try:
            signal_id = int(signal_id_entry.get())
            neighbors = neighbor_entry.get().strip()
            neighbor_ids = [int(n) for n in neighbors.split(',')] if neighbors else []
            
            processor = VideoProcessor(signal_id, neighbor_ids)
            
            if webcam_var.get():
                processor.process_video(0)  # Webcam
            else:
                file_path = filedialog.askopenfilename(filetypes=[("Video Files", "*.mp4;*.avi")])
                if file_path:
                    processor.process_video(file_path)
        except ValueError:
            messagebox.showerror("Error", "Invalid signal/neighbor ID!")

    # GUI Layout
    tk.Label(root, text="Signal ID:").pack()
    signal_id_entry = tk.Entry(root)
    signal_id_entry.pack()

    tk.Label(root, text="Neighbor IDs (comma-separated):").pack()
    neighbor_entry = tk.Entry(root)
    neighbor_entry.pack()

    webcam_var = tk.BooleanVar(value=True)
    tk.Checkbutton(root, text="Use Webcam", variable=webcam_var).pack(pady=5)

    tk.Button(root, text="Start", command=start_processing).pack(pady=10)
    root.mainloop()

if __name__ == "__main__":
    start_signal_system()
# Out:
# 0: 480x640 3 persons, 1 chair, 208.9ms
# Speed: 22.9ms preprocess, 208.9ms inference, 18.3ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 3 persons, 1 chair, 90.9ms
# Speed: 3.4ms preprocess, 90.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 95.8ms
# Speed: 3.1ms preprocess, 95.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 89.1ms
# Speed: 1.8ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair,
4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 69.2ms
# Speed: 1.4ms preprocess, 69.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 69.4ms
# Speed: 1.8ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 chair, 69.8ms
# Speed: 1.9ms preprocess, 69.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 chair, 1 laptop, 71.1ms
# Speed: 1.3ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 72.4ms
# Speed: 1.7ms preprocess, 72.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 74.1ms
# Speed: 1.4ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 1 cell phone, 67.7ms
# Speed: 2.2ms preprocess, 67.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 68.9ms
# Speed: 1.6ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 70.8ms
# Speed: 1.4ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 224 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 74.1ms
# Speed: 1.8ms preprocess, 74.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 72.2ms
# Speed: 1.8ms preprocess, 72.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.9ms
# Speed: 1.9ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 74.8ms
# Speed: 1.4ms preprocess, 74.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 76.1ms
# Speed: 1.6ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 remote, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 skateboard, 1 chair, 1 laptop, 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 76.8ms
# Speed: 1.7ms preprocess, 76.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 74.9ms
# Speed: 3.2ms preprocess, 74.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 235 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 72.8ms
# Speed: 2.5ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 100.1ms
# Speed: 1.5ms preprocess, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 remote, 68.7ms
# Speed: 2.1ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.2ms
# Speed: 1.9ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 remote, 71.3ms
# Speed: 1.4ms preprocess, 71.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 72.5ms
# Speed: 2.0ms preprocess, 72.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 68.8ms
# Speed: 2.1ms preprocess, 68.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 73.4ms
# Speed: 1.4ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 67.5ms
# Speed: 1.3ms preprocess, 67.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.7ms
# Speed: 1.6ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 71.7ms
# Speed: 2.3ms preprocess, 71.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 246 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 remote, 67.0ms
# Speed: 19.2ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 71.3ms
# Speed: 1.4ms preprocess, 71.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 72.2ms
# Speed: 1.8ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 remote, 85.6ms
# Speed: 1.4ms preprocess, 85.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 cell phone, 76.8ms
# Speed: 1.7ms preprocess, 76.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 laptop, 1 remote, 71.8ms
# Speed: 2.1ms preprocess, 71.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 cell phone, 76.7ms
# Speed: 1.7ms preprocess, 76.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 cell phone, 83.7ms
# Speed: 3.0ms preprocess, 83.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 1 cell phone, 74.1ms
# Speed: 1.4ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 cell phone, 79.7ms
# Speed: 1.5ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 257 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 cell phone, 102.1ms
# Speed: 1.6ms preprocess, 102.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 skateboard, 1 chair, 1 laptop, 1 cell phone, 69.4ms
# Speed: 1.6ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 1 cell phone, 68.0ms
# Speed: 2.1ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 cell phone, 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 1 cell phone, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 sports ball, 1 chair, 1 laptop, 1 cell phone, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 1 cell phone, 77.2ms
# Speed: 1.3ms preprocess, 77.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 cell phone, 71.9ms
# Speed: 1.9ms preprocess, 71.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 skateboard, 1 chair, 1 laptop, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 skateboard, 1 chair, 1 laptop, 1 cell phone, 72.2ms
# Speed: 1.6ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 skateboard, 1 chair, 1 laptop, 1 cell phone, 73.1ms
# Speed: 2.5ms preprocess, 73.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 268 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 2 persons, 1 skateboard, 1 chair, 1 laptop, 1 cell phone, 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 chair, 1 remote, 1 cell phone, 67.3ms
# Speed: 1.5ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 remote, 1 cell phone, 70.5ms
# Speed: 2.1ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 1 cell phone, 70.6ms
# Speed: 2.3ms preprocess, 70.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 1 cell phone, 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 71.6ms
# Speed: 1.6ms preprocess, 71.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 chair, 1 cell phone, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 70.2ms
# Speed: 2.3ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 skateboard, 1 chair, 1 laptop, 68.7ms
# Speed: 1.4ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 74.2ms
# Speed: 1.5ms preprocess, 74.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 laptop, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 279 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 80.7ms
# Speed: 1.3ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 70.7ms
# Speed: 2.2ms preprocess, 70.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 100.4ms
# Speed: 1.3ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.9ms
# Speed: 1.4ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.7ms
# Speed: 1.5ms preprocess, 68.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 70.8ms
# Speed: 1.6ms preprocess, 70.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.7ms
# Speed: 1.5ms preprocess, 68.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 77.6ms
# Speed: 1.4ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 67.8ms
# Speed: 1.9ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 290 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 68.0ms
# Speed: 1.2ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 71.3ms
# Speed: 1.5ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 73.0ms
# Speed: 1.9ms preprocess, 73.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 72.7ms
# Speed: 1.9ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 73.3ms
# Speed: 1.5ms preprocess, 73.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 71.0ms
# ...
#
# 0: 480x640 5 persons, 1 laptop, 69.1ms
# Speed: 1.7ms preprocess, 69.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 66.3ms
# Speed: 1.5ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# --- Frame 736 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 480x640 4 persons, 2 laptops, 73.9ms
# Speed: 1.4ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 72.8ms
# Speed: 1.6ms preprocess, 72.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 70.6ms
# Speed: 2.9ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 74.5ms
# Speed: 1.6ms preprocess, 74.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 73.1ms
# Speed: 1.5ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 74.0ms
# Speed: 1.4ms preprocess, 74.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 99.4ms
# Speed: 4.5ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 74.3ms
# Speed: 1.3ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons,
0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # Automatically downloads if not present

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

class TrafficSignalController:
    def __init__(self, signal_id, neighbors=None):
        self.signal_id = signal_id
        self.current_signal_time = 10
        self.max_time = 70
        self.min_time = 10
        self.neighbor_signals = {}  # Stores neighbor congestion data
        self.congestion_level = "low"
        
        # Initialize neighbors (simulated)
        if neighbors:
            for neighbor_id in neighbors:
                self.neighbor_signals[neighbor_id] = {
                    'congestion': 'low',
                    'direction': 'outgoing',
                    'last_update': time.time()
                }

    def calculate_signal_time(self, frame_vehicle_count):
        """Adjust signal time based on vehicle count & neighbor congestion"""
        # Check for any high congestion neighbors (regardless of direction)
        has_high_congestion_neighbor = any(
            data['congestion'] == 'high'
            for data in self.neighbor_signals.values()
            if time.time() - data['last_update'] <= 5  # Only consider recent updates
        )

        # If any neighbor has high congestion, enforce max 50 seconds
        if has_high_congestion_neighbor:
            max_allowed = 50
            # Print special message about the restriction
            high_neighbors = [nid for nid, data in self.neighbor_signals.items() 
                            if data['congestion'] == 'high' and time.time() - data['last_update'] <= 5]
            for neighbor_id in high_neighbors:
                print(f"Signal {self.signal_id} received from Signal {neighbor_id}: "
                      f"Congestion = high, Message: \"Don't increase the Signal Time than 50 seconds\"")
        else:
            max_allowed = 70

        # Base calculation with the determined max allowed time
        if frame_vehicle_count <= 5:
            base_time = 10
        elif 6 <= frame_vehicle_count <= 25:
            base_time = 10 + (frame_vehicle_count - 5) * 2
        else:
            base_time = 50 + (frame_vehicle_count - 25) * 0.8

        # Apply the maximum time limit strictly
        final_time = min(base_time, max_allowed)
    
        # Ensure minimum time is respected
        final_time = max(self.min_time, final_time)

        return final_time

    def update_neighbor_status(self, neighbor_id, congestion, direction):
        """Update simulated neighbor's congestion status"""
        if neighbor_id in self.neighbor_signals:
            self.neighbor_signals[neighbor_id] = {
                'congestion': congestion,
                'direction': direction,
                'last_update': time.time()
            }
            # Print the received update
            print(f"Signal {neighbor_id} received update from Signal {self.signal_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Special message if congestion is high
            if congestion == 'high':
                print(f"Signal {self.signal_id} received from Signal {neighbor_id}: "
                      f"Congestion = high, Message: \"Don't increase the Signal Time than 50 seconds\"")

    def send_congestion_update(self, congestion, direction):
        """Simulate sending congestion status to neighbors"""
        self.congestion_level = congestion
        for neighbor_id in self.neighbor_signals:
            # Print the status being sent before updating
            print(f"Signal {self.signal_id} sending to Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Simulate neighbor receiving the update
            self.update_neighbor_status(neighbor_id, congestion, direction)

class VideoProcessor:
    def __init__(self, signal_id, neighbors=None):
        self.cap = None
        self.processing = False
        self.signal_controller = TrafficSignalController(signal_id, neighbors)
        self.last_frame_details = {
            'frame_number': 0,
            'vehicle_count': 0,
            'signal_time': 10,
            'congestion_level': 'low'
        }
        self.congestion_thresholds = {'low': 10, 'medium': 25, 'high': 40}
        self.direction = 'outgoing'  # Default traffic direction

    def get_congestion_level(self, count):
        if count < self.congestion_thresholds['low']:
            return 'low'
        elif count < self.congestion_thresholds['medium']:
            return 'medium'
        else:
            return 'high'

    def process_video(self, video_source):
        self.cap = cv2.VideoCapture(video_source)
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Could not open video source!")
            return

        self.processing = True
        frame_number = 0
        last_update_time = 0

        while self.processing:
            ret, frame = self.cap.read()
            if not ret:
                break

            frame_number += 1
            results = model(frame)
            result_frame = results[0].plot()

            # Count vehicles
            vehicle_count = sum(1 for result in results for box in result.boxes 
                              if model.names[int(box.cls)] in vehicle_classes)

            congestion = self.get_congestion_level(vehicle_count)
            signal_time = self.signal_controller.calculate_signal_time(vehicle_count)

            # Update last frame details
            self.last_frame_details = {
                'frame_number': frame_number,
                'vehicle_count': vehicle_count,
                'signal_time': signal_time,
                'congestion_level': congestion
            }

            # Send congestion updates (throttled to 1 per second)
            if time.time() - last_update_time > 1:
                print(f"\n--- Frame {frame_number} Update ---")
                print(f"Current congestion at Signal {self.signal_controller.signal_id}: {congestion}")
                self.signal_controller.send_congestion_update(congestion, self.direction)
                last_update_time = time.time()

            # Display info
            self.display_info(result_frame, frame_number, vehicle_count, signal_time, congestion)
            cv2.imshow(f"Signal {self.signal_controller.signal_id}", result_frame)
            
            # Print the final allocated time for this signal
            print(f"Final allocated time for Signal {self.signal_controller.signal_id}: {signal_time:.1f} seconds")

            if cv2.waitKey(1) & 0xFF == ord('q'):
                self.stop_processing()

        self.cleanup()

    def display_info(self, frame, frame_num, vehicles, signal_time, congestion):
        cv2.putText(frame, f"Signal {self.signal_controller.signal_id}", (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"Vehicles: {vehicles}", (10, 70), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Signal Time: {signal_time:.1f}s", (10, 110), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        color = (0, 0, 255) if congestion == 'high' else (0, 255, 0) if congestion == 'medium' else (255, 255, 0)
        cv2.putText(frame, f"Congestion: {congestion}", (10, 150), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        cv2.putText(frame, "Press 'q' to stop", (10, 190), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    def stop_processing(self):
        self.processing = False

    def cleanup(self):
        if self.cap:
            self.cap.release()
        cv2.destroyAllWindows()

def start_signal_system():
    root = tk.Tk()
    root.title("Traffic Signal Controller")
    root.geometry("400x250")

    def start_processing():
        try:
            signal_id = int(signal_id_entry.get())
            neighbors = neighbor_entry.get().strip()
            neighbor_ids = [int(n) for n in neighbors.split(',')] if neighbors else []
            
            # Ask for initial congestion status of each neighbor
            neighbor_status = {}
            for neighbor_id in neighbor_ids:
                status = simpledialog.askstring("Neighbor Status", 
                                               f"Enter initial congestion status for Signal {neighbor_id} (low/medium/high):")
                direction = simpledialog.askstring("Traffic Direction", 
                                                 f"Enter traffic direction for Signal {neighbor_id} (incoming/outgoing):")
                neighbor_status[neighbor_id] = {
                    'congestion': status.lower() if status else 'low',
                    'direction': direction.lower() if direction else 'outgoing'
                }
            
            processor = VideoProcessor(signal_id, neighbor_ids)
            
            # Set initial neighbor statuses
            for neighbor_id, status in neighbor_status.items():
                processor.signal_controller.neighbor_signals[neighbor_id] = {
                    'congestion': status['congestion'],
                    'direction': status['direction'],
                    'last_update': time.time()
                }
            
            if webcam_var.get():
                processor.process_video(0)  # Webcam
            else:
                file_path = filedialog.askopenfilename(filetypes=[("Video Files", "*.mp4;*.avi")])
                if file_path:
                    processor.process_video(file_path)
        except ValueError:
            messagebox.showerror("Error", "Invalid signal/neighbor ID!")

    # GUI Layout
    tk.Label(root, text="Signal ID:").pack()
    signal_id_entry = tk.Entry(root)
    signal_id_entry.pack()

    tk.Label(root, text="Neighbor IDs (comma-separated):").pack()
    neighbor_entry = tk.Entry(root)
    neighbor_entry.pack()

    webcam_var = tk.BooleanVar(value=True)
    tk.Checkbutton(root, text="Use Webcam", variable=webcam_var).pack(pady=5)

    tk.Button(root, text="Start", command=start_processing).pack(pady=10)
    root.mainloop()

if __name__ == "__main__":
    start_signal_system()
# Out:
# 0: 384x640 12 persons, 22 cars, 14 motorcycles, 2 trucks, 128.0ms
# Speed: 9.1ms preprocess, 128.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 21 cars, 12 motorcycles, 2 trucks, 98.8ms
# Speed: 5.5ms preprocess, 98.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 16 persons, 20 cars, 14 motorcycles, 4 trucks, 84.2ms
# Speed: 3.2ms preprocess, 84.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 20 cars, 14 motorcycles, 4 trucks, 67.1ms
# Speed: 3.3ms preprocess, 67.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 21 cars, 17 motorcycles, 3 trucks, 67.8ms
# Speed: 3.5ms preprocess, 67.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 19 cars, 18 motorcycles, 4 trucks, 69.1ms
# Speed: 3.3ms preprocess, 69.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 20 cars, 15 motorcycles, 4 trucks, 69.0ms
# Speed: 3.7ms preprocess, 69.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 9 persons, 20 cars, 13 motorcycles, 5 trucks, 70.2ms
# Speed: 3.3ms preprocess, 70.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 8 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 21 cars, 15 motorcycles, 5 trucks, 68.2ms
# Speed: 2.9ms preprocess, 68.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 20 cars, 16 motorcycles, 5 trucks, 66.6ms
# Speed: 3.4ms preprocess, 66.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 17 motorcycles, 4 trucks, 69.4ms
# Speed: 3.3ms preprocess, 69.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 13 motorcycles, 4 trucks, 69.1ms
# Speed: 3.6ms preprocess, 69.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 19 cars, 17 motorcycles, 5 trucks, 68.5ms
# Speed: 3.6ms preprocess, 68.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 21 cars, 19 motorcycles, 5 trucks, 91.2ms
# Speed: 3.4ms preprocess, 91.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 16 persons, 21 cars, 16 motorcycles, 3 trucks, 66.8ms
# Speed: 3.1ms preprocess, 66.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 15 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 16 cars, 14 motorcycles, 5 trucks, 70.0ms
# Speed: 3.2ms preprocess, 70.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 17 cars, 14 motorcycles, 5 trucks, 70.1ms
# Speed: 3.0ms preprocess, 70.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 13 motorcycles, 3 trucks, 68.4ms
# Speed: 3.1ms preprocess, 68.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 17 cars, 11 motorcycles, 3 trucks, 71.4ms
# Speed: 3.8ms preprocess, 71.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 17 cars, 10 motorcycles, 4 trucks, 69.1ms
# Speed: 10.6ms preprocess, 69.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 15 persons, 18 cars, 11 motorcycles, 3 trucks, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 17 cars, 11 motorcycles, 3 trucks, 70.3ms
# Speed: 2.6ms preprocess, 70.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 19 cars, 15 motorcycles, 2 trucks, 68.1ms
# Speed: 2.9ms preprocess, 68.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 23 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 17 cars, 14 motorcycles, 4 trucks, 72.1ms
# Speed: 3.1ms preprocess, 72.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 17 cars, 13 motorcycles, 4 trucks, 69.3ms
# Speed: 4.3ms preprocess, 69.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 17 cars, 17 motorcycles, 2 trucks, 70.0ms
# Speed: 2.9ms preprocess, 70.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons,
0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 7 persons, 23 cars, 11 motorcycles, 1 truck, 60.5ms
# Speed: 2.7ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 227 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 23 cars, 12 motorcycles, 1 truck, 57.9ms
# Speed: 3.6ms preprocess, 57.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 8 persons, 24 cars, 12 motorcycles, 1 truck, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 8 persons, 23 cars, 13 motorcycles, 1 truck, 61.1ms
# Speed: 3.8ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 7 persons, 23 cars, 10 motorcycles, 1 truck, 70.4ms
# Speed: 4.4ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 7 persons, 24 cars, 11 motorcycles, 1 truck, 60.5ms
# Speed: 3.3ms preprocess, 60.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds

# %% [markdown]
# ### Basic Concept:
# Each traffic signal constantly monitors its own congestion and shares this info with its neighbors. When it receives updates from neighbors, it adjusts its timing to help balance traffic flow across the whole area.
#
# ### How It Works Step-by-Step:
#
# 1. **Each Signal Knows Its Neighbors**
#    - When you start the system, you tell each signal who its neighbors are (like Signal 1 knows Signals 2 and 3 are its neighbors)
#
# 2. **Constant Monitoring**
#    - Each signal counts vehicles at its intersection every second
#    - Determines if congestion is Low/Medium/High based on vehicle count
#
# 3. **Sharing Updates**
#    - Every second, each signal sends messages like:
#      *"Hey Neighbor! I'm Signal 1, my congestion is High, and traffic is coming your way (incoming)"*
#
# 4. **Making Adjustments**
#    When a signal gets updates from neighbors, it changes its timing like this:
#    - **If neighbor has HIGH congestion** and traffic is coming your way:
#      *Increase your green time* → Helps clear their backlog
#    - **If neighbor has LOW congestion** and traffic is going away from you:
#      *Decrease your green time* → Lets other busier signals get more time
#    - Uses simple math: Base time (from its own traffic) + Adjustments (from neighbors)
#
# 5. **Safety Limits**
#    - Never goes below minimum (e.g., 10 seconds)
#    - Never goes above maximum (e.g., 70 seconds)
#
# ### Simple Example:
#
# Signal 1 (Congestion: High) → Signal 2:
# - Signal 2 sees: "Signal 1 is jammed and traffic is coming my way"
# - Signal 2 responds: "I'll stay green longer to help clear Signal 1's traffic"
#
# Signal 3 (Congestion: Low) → Signal 2:
# - Signal 2 sees: "Signal 3 is clear and traffic is moving away"
# - Signal 2 responds: "I can reduce my green time since Signal 3 doesn't need help"
#
# ### Final Decision:
# Signal 2 combines:
# - Its own traffic count
# - Signal 1's "help needed" message (+5 seconds)
# - Signal 3's "all clear" message (-2 seconds)
# = Final timing adjustment
#
# This way, all signals work together like a team to keep traffic flowing smoothly across multiple intersections!

# %%
# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # Automatically downloads if not present

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

class TrafficSignalController:
    def __init__(self, signal_id, neighbors=None):
        self.signal_id = signal_id
        self.current_signal_time = 10
        self.max_time = 70
        self.min_time = 10
        self.neighbor_signals = {}  # Stores neighbor congestion data
        self.congestion_level = "low"
        
        # Initialize neighbors (simulated)
        if neighbors:
            for neighbor_id in neighbors:
                self.neighbor_signals[neighbor_id] = {
                    'congestion': 'low',  # Default will be overwritten by user input
                    'direction': 'outgoing',
                    'last_update': time.time()
                }

    def calculate_signal_time(self, frame_vehicle_count):
        """Adjust signal time based on vehicle count & neighbor congestion"""
        # Check for any high congestion neighbors (regardless of direction)
        has_high_congestion_neighbor = any(
            data['congestion'] == 'high'
            for data in self.neighbor_signals.values()
            if time.time() - data['last_update'] <= 5  # Only consider recent updates
        )

        # If any neighbor has high congestion, enforce max 50 seconds
        if has_high_congestion_neighbor:
            max_allowed = 50
            # Print special message about the restriction
            high_neighbors = [nid for nid, data in self.neighbor_signals.items() 
                            if data['congestion'] == 'high' and time.time() - data['last_update'] <= 5]
            for neighbor_id in high_neighbors:
                print(f"Signal {self.signal_id} received from Signal {neighbor_id}: "
                      f"Congestion = high, Message: \"Don't increase the Signal Time than 50 seconds\"")
        else:
            max_allowed = 70

        # Base calculation with the determined max allowed time
        if frame_vehicle_count <= 5:
            base_time = 10
        elif 6 <= frame_vehicle_count <= 25:
            base_time = 10 + (frame_vehicle_count - 5) * 2
        else:
            base_time = 50 + (frame_vehicle_count - 25) * 0.8

        # Apply the maximum time limit strictly
        final_time = min(base_time, max_allowed)
    
        # Ensure minimum time is respected
        final_time = max(self.min_time, final_time)

        return final_time

    def update_neighbor_status(self, neighbor_id, congestion, direction):
        """Update simulated neighbor's congestion status"""
        if neighbor_id in self.neighbor_signals:
            self.neighbor_signals[neighbor_id] = {
                'congestion': congestion,
                'direction': direction,
                'last_update': time.time()
            }
            # Print the received update
            print(f"Signal {self.signal_id} received update from Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Special message if congestion is high
            if congestion == 'high':
                print(f"Signal {self.signal_id} received from Signal {neighbor_id}: "
                      f"Congestion = high, Message: \"Don't increase the Signal Time than 50 seconds\"")

    def send_congestion_update(self, congestion, direction):
        """Simulate sending congestion status to neighbors"""
        self.congestion_level = congestion
        for neighbor_id in self.neighbor_signals:
            # Print the status being sent before updating
            print(f"Signal {self.signal_id} sending to Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Simulate neighbor receiving the update
            self.update_neighbor_status(neighbor_id, congestion, direction)

class VideoProcessor:
    def __init__(self, signal_id, neighbors=None, initial_neighbor_status=None):
        self.cap = None
        self.processing = False
        self.signal_controller = TrafficSignalController(signal_id, neighbors)
        self.last_frame_details = {
            'frame_number': 0,
            'vehicle_count': 0,
            'signal_time': 10,
            'congestion_level': 'low'
        }
        self.congestion_thresholds = {'low': 10, 'medium': 25, 'high': 40}
        self.direction = 'outgoing'  # Default traffic direction

        # Set initial neighbor statuses if provided
        if initial_neighbor_status:
            for neighbor_id, status in initial_neighbor_status.items():
                self.signal_controller.neighbor_signals[neighbor_id] = {
                    'congestion': status['congestion'],
                    'direction': status['direction'],
                    'last_update': time.time()
                }

    def get_congestion_level(self, count):
        if count < self.congestion_thresholds['low']:
            return 'low'
        elif count < self.congestion_thresholds['medium']:
            return 'medium'
        else:
            return 'high'

    def process_video(self, video_source):
        self.cap = cv2.VideoCapture(video_source)
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Could not open video source!")
            return

        self.processing = True
        frame_number = 0
        last_update_time = 0

        while self.processing:
            ret, frame = self.cap.read()
            if not ret:
                break

            frame_number += 1
            results = model(frame)
            result_frame = results[0].plot()

            # Count vehicles
            vehicle_count = sum(1 for result in results for box in result.boxes 
                              if model.names[int(box.cls)] in vehicle_classes)

            congestion = self.get_congestion_level(vehicle_count)
            signal_time = self.signal_controller.calculate_signal_time(vehicle_count)

            # Update last frame details
            self.last_frame_details = {
                'frame_number': frame_number,
                'vehicle_count': vehicle_count,
                'signal_time': signal_time,
                'congestion_level': congestion
            }

            # Send congestion updates (throttled to 1 per second)
            if time.time() - last_update_time > 1:
                print(f"\n--- Frame {frame_number} Update ---")
                print(f"Current congestion at Signal {self.signal_controller.signal_id}: {congestion}")
                self.signal_controller.send_congestion_update(congestion, self.direction)
                last_update_time = time.time()

            # Display info
            self.display_info(result_frame, frame_number, vehicle_count, signal_time, congestion)
            cv2.imshow(f"Signal {self.signal_controller.signal_id}", result_frame)
            
            # Print the final allocated time for this signal
            print(f"Final allocated time for Signal {self.signal_controller.signal_id}: {signal_time:.1f} seconds")

            if cv2.waitKey(1) & 0xFF == ord('q'):
                self.stop_processing()

        self.cleanup()

    def display_info(self, frame, frame_num, vehicles, signal_time, congestion):
        cv2.putText(frame, f"Signal {self.signal_controller.signal_id}", (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"Vehicles: {vehicles}", (10, 70), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Signal Time: {signal_time:.1f}s", (10, 110), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        color = (0, 0, 255) if congestion == 'high' else (0, 255, 0) if congestion == 'medium' else (255, 255, 0)
        cv2.putText(frame, f"Congestion: {congestion}", (10, 150), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        cv2.putText(frame, "Press 'q' to stop", (10, 190), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    def stop_processing(self):
        self.processing = False

    def cleanup(self):
        if self.cap:
            self.cap.release()
        cv2.destroyAllWindows()

def start_signal_system():
    root = tk.Tk()
    root.title("Traffic Signal Controller")
    root.geometry("400x250")

    def start_processing():
        try:
            signal_id = int(signal_id_entry.get())
            neighbors = neighbor_entry.get().strip()
            neighbor_ids = [int(n) for n in neighbors.split(',')] if neighbors else []
            
            # Ask for initial congestion status of each neighbor
            neighbor_status = {}
            for neighbor_id in neighbor_ids:
                while True:
                    status = simpledialog.askstring("Neighbor Status", 
                                                  f"Enter initial congestion status for Signal {neighbor_id} (low/medium/high):")
                    if status and status.lower() in ['low', 'medium', 'high']:
                        break
                    messagebox.showwarning("Invalid Input", "Please enter 'low', 'medium', or 'high'")
                
                while True:
                    direction = simpledialog.askstring("Traffic Direction", 
                                                     f"Enter traffic direction for Signal {neighbor_id} (incoming/outgoing):")
                    if direction and direction.lower() in ['incoming', 'outgoing']:
                        break
                    messagebox.showwarning("Invalid Input", "Please enter 'incoming' or 'outgoing'")
                
                neighbor_status[neighbor_id] = {
                    'congestion': status.lower(),
                    'direction': direction.lower()
                }
            
            # Create processor with initial neighbor statuses
            processor = VideoProcessor(signal_id, neighbor_ids, neighbor_status)
            
            if webcam_var.get():
                processor.process_video(0)  # Webcam
            else:
                file_path = filedialog.askopenfilename(filetypes=[("Video Files", "*.mp4;*.avi")])
                if file_path:
                    processor.process_video(file_path)
        except ValueError:
            messagebox.showerror("Error", "Invalid signal/neighbor ID!")

    # GUI Layout
    tk.Label(root, text="Signal ID:").pack()
    signal_id_entry = tk.Entry(root)
    signal_id_entry.pack()

    tk.Label(root, text="Neighbor IDs (comma-separated):").pack()
    neighbor_entry = tk.Entry(root)
    neighbor_entry.pack()

    webcam_var = tk.BooleanVar(value=True)
    tk.Checkbutton(root, text="Use Webcam", variable=webcam_var).pack(pady=5)

    tk.Button(root, text="Start", command=start_processing).pack(pady=10)
    root.mainloop()

if __name__ == "__main__":
    start_signal_system()
# Out:
# 0: 384x640 12 persons, 22 cars, 14 motorcycles, 2 trucks, 86.1ms
# Speed: 4.6ms preprocess, 86.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 11 persons, 21 cars, 12 motorcycles, 2 trucks, 82.0ms
# Speed: 3.1ms preprocess, 82.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 16 persons, 20 cars, 14 motorcycles, 4 trucks, 76.1ms
# Speed: 3.6ms preprocess, 76.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 20 cars, 14 motorcycles, 4 trucks, 73.2ms
# Speed: 3.7ms preprocess, 73.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 21 cars, 17 motorcycles, 3 trucks, 74.6ms
# Speed: 3.5ms preprocess, 74.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 19 cars, 18 motorcycles, 4 trucks, 76.6ms
# Speed: 3.4ms preprocess, 76.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 20 cars, 15 motorcycles, 4 trucks, 69.6ms
# Speed: 3.3ms preprocess, 69.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 9 persons, 20 cars, 13 motorcycles, 5 trucks, 78.3ms
# Speed: 3.6ms preprocess, 78.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 8 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 21 cars, 15 motorcycles, 5 trucks, 54.1ms
# Speed: 2.4ms preprocess, 54.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 20 cars, 16 motorcycles, 5 trucks, 54.0ms
# Speed: 2.6ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 17 motorcycles, 4 trucks, 52.7ms
# Speed: 2.4ms preprocess, 52.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 13 motorcycles, 4 trucks, 50.1ms
# Speed: 2.5ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 19 cars, 17 motorcycles, 5 trucks, 51.9ms
# Speed: 2.5ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 21 cars, 19 motorcycles, 5 trucks, 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 16 persons, 21 cars, 16 motorcycles, 3 trucks, 52.5ms
# Speed: 2.4ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 16 cars, 14 motorcycles, 5 trucks, 48.8ms
# Speed: 2.4ms preprocess, 48.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 17 cars, 14 motorcycles, 5 trucks, 75.8ms
# Speed: 3.3ms preprocess, 75.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 13 motorcycles, 3 trucks, 51.4ms
# Speed: 2.8ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 18 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 17 cars, 11 motorcycles, 3 trucks, 49.6ms
# Speed: 2.8ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 17 cars, 10 motorcycles, 4 trucks, 51.4ms
# Speed: 2.4ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 15 persons, 18 cars, 11 motorcycles, 3 trucks, 49.1ms
# Speed: 2.6ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 17 cars, 11 motorcycles, 3 trucks, 49.1ms
# Speed: 2.4ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 19 cars, 15 motorcycles, 2 trucks, 53.6ms
# Speed: 2.1ms preprocess, 53.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 17 cars, 14 motorcycles, 4 trucks, 50.7ms
# Speed: 2.7ms preprocess, 50.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 17 cars, 13 motorcycles, 4 trucks, 51.5ms
# Speed: 2.9ms preprocess, 51.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 17 cars, 17 motorcycles, 2 trucks, 54.9ms
# Speed: 2.4ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 18 cars, 18 motorcycles, 2 trucks, 54.2ms
# Speed: 2.9ms preprocess, 54.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 18 cars, 16 motorcycles, 6 trucks, 51.3ms
# Speed: 2.5ms preprocess, 51.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 18 cars, 16 motorcycles, 5 trucks, 51.7ms
# Speed: 2.5ms preprocess, 51.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 29 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 19 cars, 14 motorcycles, 5 trucks, 51.3ms
# Speed: 2.7ms preprocess, 51.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 19 cars, 15 motorcycles, 5 trucks, 50.9ms
# Speed: 2.4ms preprocess, 50.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 19 cars, 17 motorcycles, 5 trucks, 49.9ms
# Speed: 2.2ms preprocess, 49.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 19 cars, 18 motorcycles, 4 trucks, 50.4ms
# Speed: 2.5ms preprocess, 50.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 18 cars, 15 motorcycles, 4 trucks, 53.4ms
# Speed: 2.5ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 8 persons, 19 cars, 14 motorcycles, 4 trucks, 55.8ms
# Speed: 2.4ms preprocess, 55.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 9 persons, 19 cars, 13 motorcycles, 4 trucks, 51.5ms
# Speed: 2.7ms preprocess, 51.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 19 cars, 13 motorcycles, 5 trucks, 50.5ms
# Speed: 2.9ms preprocess, 50.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 19 cars, 11 motorcycles, 4 trucks, 50.0ms
# Speed: 2.4ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 19 cars, 12 motorcycles, 6 trucks, 55.7ms
# Speed: 3.5ms preprocess, 55.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
#
# --- Frame 39 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 19 cars, 14 motorcycles, 5 trucks, 55.2ms
# Speed: 2.1ms preprocess, 55.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 13 persons, 20 cars, 12 motorcycles, 4 trucks, 52.6ms
# Speed: 3.7ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 12 motorcycles, 3 trucks, 52.2ms
# Speed: 3.0ms preprocess, 52.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 20 cars, 14 motorcycles, 3 trucks, 52.8ms
# Speed: 2.4ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 20 cars, 16 motorcycles, 4 trucks, 53.8ms
# Speed: 2.4ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 11 persons, 21 cars, 13 motorcycles, 3 trucks, 50.2ms
# Speed: 2.4ms preprocess, 50.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 12 persons, 21 cars, 11 motorcycles, 4 trucks, 50.7ms
# Speed: 2.3ms preprocess, 50.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds
#
# 0: 384x640 10 persons, 20 cars, 10 motorcycles, 3 trucks, 50.6ms
# Speed: 3.1ms preprocess, 50.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Signal 1 received from Signal 2: Congestion = high, Message: "Don't increase the Signal Time than 50 seconds"
# Final allocated time for Signal 1: 50.0 seconds

# %%
# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # Automatically downloads if not present

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

class TrafficSignalController:
    def __init__(self, signal_id, neighbors=None):
        self.signal_id = signal_id
        self.current_signal_time = 10
        self.max_time = 70
        self.min_time = 10
        self.neighbor_signals = {}  # Stores neighbor congestion data
        self.congestion_level = "low"
        
        # Initialize neighbors (simulated)
        if neighbors:
            for neighbor_id, status in neighbors.items():
                self.neighbor_signals[neighbor_id] = {
                    'congestion': status['congestion'],
                    'direction': status['direction'],
                    'last_update': time.time()
                }

    def calculate_signal_time(self, frame_vehicle_count):
        """Adjust signal time based on vehicle count & neighbor congestion"""
        # Check for any high congestion neighbors with incoming direction
        has_high_incoming_neighbor = any(
            data['congestion'] in ['high', 'medium'] and data['direction'] == 'incoming'
            for data in self.neighbor_signals.values()
            if time.time() - data['last_update'] <= 5  # Only consider recent updates
        )

        # If any incoming neighbor has high/medium congestion, enforce max 50 seconds
        if has_high_incoming_neighbor:
            max_allowed = 50
            # Print special message about the restriction
            high_neighbors = [nid for nid, data in self.neighbor_signals.items() 
                            if data['congestion'] in ['high', 'medium'] and 
                            data['direction'] == 'incoming' and 
                            time.time() - data['last_update'] <= 5]
            for neighbor_id in high_neighbors:
                print(f"Signal {self.signal_id} received from Signal {neighbor_id}: "
                      f"Congestion = {data['congestion']}, Direction = incoming, "
                      f"Message: \"Don't increase the Signal Time beyond 50 seconds\"")
        else:
            max_allowed = 70

        # Base calculation with the determined max allowed time
        if frame_vehicle_count <= 5:
            base_time = 10
        elif 6 <= frame_vehicle_count <= 25:
            base_time = 10 + (frame_vehicle_count - 5) * 2
        else:
            base_time = 50 + (frame_vehicle_count - 25) * 0.8

        # Apply the maximum time limit strictly
        final_time = min(base_time, max_allowed)
    
        # Ensure minimum time is respected
        final_time = max(self.min_time, final_time)

        return final_time

    def update_neighbor_status(self, neighbor_id, congestion, direction):
        """Update simulated neighbor's congestion status"""
        if neighbor_id in self.neighbor_signals:
            self.neighbor_signals[neighbor_id] = {
                'congestion': congestion,
                'direction': direction,
                'last_update': time.time()
            }
            # Print the received update
            print(f"Signal {self.signal_id} received update from Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Special message if congestion is high/medium and direction is incoming
            if congestion in ['high', 'medium'] and direction == 'incoming':
                print(f"Signal {self.signal_id} received from Signal {neighbor_id}: "
                      f"Congestion = {congestion}, Direction = incoming, "
                      f"Message: \"Don't increase the Signal Time beyond 50 seconds\"")

    def send_congestion_update(self, congestion, direction):
        """Simulate sending congestion status to neighbors"""
        self.congestion_level = congestion
        for neighbor_id in self.neighbor_signals:
            # Print the status being sent before updating
            print(f"Signal {self.signal_id} sending to Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Simulate neighbor receiving the update
            self.update_neighbor_status(neighbor_id, congestion, direction)

class VideoProcessor:
    def __init__(self, signal_id, neighbors=None):
        self.cap = None
        self.processing = False
        self.signal_controller = TrafficSignalController(signal_id, neighbors)
        self.last_frame_details = {
            'frame_number': 0,
            'vehicle_count': 0,
            'signal_time': 10,
            'congestion_level': 'low'
        }
        self.congestion_thresholds = {'low': 10, 'medium': 25, 'high': 40}
        self.direction = 'outgoing'  # Default traffic direction

    def get_congestion_level(self, count):
        if count < self.congestion_thresholds['low']:
            return 'low'
        elif count < self.congestion_thresholds['medium']:
            return 'medium'
        else:
            return 'high'

    def process_video(self, video_source):
        self.cap = cv2.VideoCapture(video_source)
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Could not open video source!")
            return

        self.processing = True
        frame_number = 0
        last_update_time = 0

        while self.processing:
            ret, frame = self.cap.read()
            if not ret:
                break

            frame_number += 1
            results = model(frame)
            result_frame = results[0].plot()

            # Count vehicles
            vehicle_count = sum(1 for result in results for box in result.boxes 
                              if model.names[int(box.cls)] in vehicle_classes)

            congestion = self.get_congestion_level(vehicle_count)
            signal_time = self.signal_controller.calculate_signal_time(vehicle_count)

            # Update last frame details
            self.last_frame_details = {
                'frame_number': frame_number,
                'vehicle_count': vehicle_count,
                'signal_time': signal_time,
                'congestion_level': congestion
            }

            # Send congestion updates (throttled to 1 per second)
            if time.time() - last_update_time > 1:
                print(f"\n--- Frame {frame_number} Update ---")
                print(f"Current congestion at Signal {self.signal_controller.signal_id}: {congestion}")
                self.signal_controller.send_congestion_update(congestion, self.direction)
                last_update_time = time.time()

            # Display info
            self.display_info(result_frame, frame_number, vehicle_count, signal_time, congestion)
            cv2.imshow(f"Signal {self.signal_controller.signal_id}", result_frame)
            
            # Print the final allocated time for this signal
            print(f"Final allocated time for Signal {self.signal_controller.signal_id}: {signal_time:.1f} seconds")

            if cv2.waitKey(1) & 0xFF == ord('q'):
                self.stop_processing()

        self.cleanup()

    def display_info(self, frame, frame_num, vehicles, signal_time, congestion):
        cv2.putText(frame, f"Signal {self.signal_controller.signal_id}", (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"Vehicles: {vehicles}", (10, 70), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Signal Time: {signal_time:.1f}s", (10, 110), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        color = (0, 0, 255) if congestion == 'high' else (0, 255, 0) if congestion == 'medium' else (255, 255, 0)
        cv2.putText(frame, f"Congestion: {congestion}", (10, 150), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        cv2.putText(frame, "Press 'q' to stop", (10, 190), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    def stop_processing(self):
        self.processing = False

    def cleanup(self):
        if self.cap:
            self.cap.release()
        cv2.destroyAllWindows()

def start_signal_system():
    root = tk.Tk()
    root.title("Traffic Signal Controller")
    root.geometry("400x250")

    def start_processing():
        try:
            signal_id = int(signal_id_entry.get())
            neighbors = neighbor_entry.get().strip()
            neighbor_ids = [int(n.strip()) for n in neighbors.split(',')] if neighbors else []
            
            # Ask for initial congestion status and direction of each neighbor
            neighbor_status = {}
            for neighbor_id in neighbor_ids:
                status = simpledialog.askstring("Neighbor Status", 
                                               f"Enter initial congestion status for Signal {neighbor_id} (low/medium/high):")
                direction = simpledialog.askstring("Traffic Direction", 
                                                 f"Enter traffic direction for Signal {neighbor_id} (incoming/outgoing):")
                neighbor_status[neighbor_id] = {
                    'congestion': status.lower() if status else 'low',
                    'direction': direction.lower() if direction else 'outgoing'
                }
            
            processor = VideoProcessor(signal_id, neighbor_status)
            
            # Set traffic direction for this signal
            direction = simpledialog.askstring("Traffic Direction", 
                                             f"Enter traffic direction for Signal {signal_id} (incoming/outgoing):")
            if direction:
                processor.direction = direction.lower()
            
            if webcam_var.get():
                processor.process_video(0)  # Webcam
            else:
                file_path = filedialog.askopenfilename(filetypes=[("Video Files", "*.mp4;*.avi")])
                if file_path:
                    processor.process_video(file_path)
        except ValueError:
            messagebox.showerror("Error", "Invalid signal/neighbor ID!")

    # GUI Layout
    tk.Label(root, text="Signal ID:").pack()
    signal_id_entry = tk.Entry(root)
    signal_id_entry.pack()

    tk.Label(root, text="Neighbor IDs (comma-separated):").pack()
    neighbor_entry = tk.Entry(root)
    neighbor_entry.pack()

    webcam_var = tk.BooleanVar(value=True)
    tk.Checkbutton(root, text="Use Webcam", variable=webcam_var).pack(pady=5)

    tk.Button(root, text="Start", command=start_processing).pack(pady=10)
    root.mainloop()

if __name__ == "__main__":
    start_signal_system()
# Out:
# 0: 384x640 12 persons, 22 cars, 14 motorcycles, 2 trucks, 101.5ms
# Speed: 6.3ms preprocess, 101.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 11 persons, 21 cars, 12 motorcycles, 2 trucks, 126.2ms
# Speed: 4.6ms preprocess, 126.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.0 seconds
#
# 0: 384x640 16 persons, 20 cars, 14 motorcycles, 4 trucks, 97.1ms
# Speed: 4.3ms preprocess, 97.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 10 persons, 20 cars, 14 motorcycles, 4 trucks, 66.3ms
# Speed: 3.5ms preprocess, 66.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 13 persons, 21 cars, 17 motorcycles, 3 trucks, 64.7ms
# Speed: 3.3ms preprocess, 64.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 13 persons, 19 cars, 18 motorcycles, 4 trucks, 66.7ms
# Speed: 2.9ms preprocess, 66.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 10 persons, 20 cars, 15 motorcycles, 4 trucks, 67.9ms
# Speed: 3.1ms preprocess, 67.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 61.2 seconds
#
# 0: 384x640 9 persons, 20 cars, 13 motorcycles, 5 trucks, 67.5ms
# Speed: 3.8ms preprocess, 67.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 8 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 11 persons, 21 cars, 15 motorcycles, 5 trucks, 66.0ms
# Speed: 2.9ms preprocess, 66.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 11 persons, 20 cars, 16 motorcycles, 5 trucks, 63.0ms
# Speed: 3.2ms preprocess, 63.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 12 persons, 20 cars, 17 motorcycles, 4 trucks, 65.2ms
# Speed: 2.9ms preprocess, 65.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 12 persons, 20 cars, 13 motorcycles, 4 trucks, 62.7ms
# Speed: 4.5ms preprocess, 62.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 59.6 seconds
#
# 0: 384x640 11 persons, 19 cars, 17 motorcycles, 5 trucks, 66.2ms
# Speed: 2.7ms preprocess, 66.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 13 persons, 21 cars, 19 motorcycles, 5 trucks, 71.9ms
# Speed: 3.4ms preprocess, 71.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 66.0 seconds
#
# 0: 384x640 16 persons, 21 cars, 16 motorcycles, 3 trucks, 90.9ms
# Speed: 3.0ms preprocess, 90.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.0 seconds
#
# 0: 384x640 11 persons, 16 cars, 14 motorcycles, 5 trucks, 67.5ms
# Speed: 2.7ms preprocess, 67.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 16 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Final allocated time for Signal 1: 58.0 seconds
#
# 0: 384x640 11 persons, 17 cars, 14 motorcycles, 5 trucks, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.8 seconds
#
# 0: 384x640 12 persons, 20 cars, 13 motorcycles, 3 trucks, 72.1ms
# Speed: 3.4ms preprocess, 72.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.8 seconds
#
# 0: 384x640 12 persons, 17 cars, 11 motorcycles, 3 trucks, 67.8ms
# Speed: 3.2ms preprocess, 67.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 54.8 seconds
#
# 0: 384x640 13 persons, 17 cars, 10 motorcycles, 4 trucks, 62.8ms
# Speed: 2.8ms preprocess, 62.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1:
2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 59.6 seconds
#
# 0: 384x640 14 persons, 24 cars, 11 motorcycles, 4 trucks, 60.5ms
# Speed: 2.3ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 64 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Final allocated time for Signal 1: 61.2 seconds
#
# 0: 384x640 13 persons, 24 cars, 13 motorcycles, 3 trucks, 73.1ms
# Speed: 3.8ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.0 seconds
#
# 0: 384x640 14 persons, 23 cars, 12 motorcycles, 3 trucks, 58.3ms
# Speed: 2.3ms preprocess, 58.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 11 persons, 23 cars, 11 motorcycles, 4 trucks, 52.9ms
# Speed: 3.0ms preprocess, 52.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 10 persons, 23 cars, 9 motorcycles, 4 trucks, 52.0ms
# Speed: 2.7ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.8 seconds
#
# 0: 384x640 12 persons, 23 cars, 12 motorcycles, 5 trucks, 50.8ms
# Speed: 2.4ms preprocess, 50.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.0 seconds
#
# 0: 384x640 11 persons, 23 cars, 9 motorcycles, 4 trucks, 52.6ms
# Speed: 2.2ms preprocess, 52.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.8 seconds
#
# 0: 384x640 10 persons, 20 cars, 10 motorcycles, 5 trucks, 54.3ms
# Speed: 2.3ms preprocess, 54.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.0 seconds
#
# 0: 384x640 11 persons, 19 cars, 9 motorcycles, 6 trucks, 55.4ms
# Speed: 2.4ms preprocess, 55.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 57.2 seconds
#
# 0: 384x640 12 persons, 20 cars, 9 motorcycles, 3 trucks, 51.9ms
# Speed: 2.6ms preprocess, 51.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 55.6 seconds
#
# 0: 384x640 11 persons, 20 cars, 9 motorcycles, 3 trucks, 53.1ms
# Speed: 2.4ms preprocess, 53.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 74 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Final allocated time for Signal 1: 55.6 seconds
#
# 0: 384x640 11 persons, 21 cars, 11 motorcycles, 3 trucks, 50.9ms
# Speed: 2.4ms preprocess, 50.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.0 seconds
#
# 0: 384x640 12 persons, 24 cars, 10 motorcycles, 3 trucks, 60.6ms
# Speed: 2.5ms preprocess, 60.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 59.6 seconds
#
# 0: 384x640 15 persons, 23 cars, 11 motorcycles, 3 trucks, 53.4ms
# Speed: 3.1ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 59.6 seconds
#
# 0: 384x640 18 persons, 24 cars, 11 motorcycles, 3 trucks, 53.8ms
# Speed: 2.7ms preprocess, 53.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 14 persons, 25 cars, 11 motorcycles, 4 trucks, 51.9ms
# Speed: 2.2ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.0 seconds
#
# 0: 384x640 14 persons, 20 cars, 11 motorcycles, 4 trucks, 54.8ms
# Speed: 2.6ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 58.0 seconds
#
# 0: 384x640 15 persons, 23 cars, 12 motorcycles, 4 trucks, 52.0ms
# Speed: 3.1ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 61.2 seconds
#
# 0: 384x640 16 persons, 24 cars, 14 motorcycles, 4 trucks, 55.4ms
# Speed: 2.4ms preprocess, 55.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 63.6 seconds
#
# 0: 384x640 14 persons, 24 cars, 13 motorcycles, 5 trucks, 77.1ms
# Speed: 2.5ms preprocess, 77.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 63.6 seconds
#
# 0: 384x640 14 persons, 21 cars, 13 motorcycles, 4 trucks, 53.6ms
# Speed: 2.7ms preprocess, 53.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 84 Update ---
# Current congestion at Signal 1: high
# Signal 1 sending to Signal 2: Congestion = high, Direction = outgoing
# Signal 1 received update from Signal 2: Congestion = high, Direction = outgoing
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 14 persons, 21 cars, 12 motorcycles, 4 trucks, 52.3ms
# Speed: 2.2ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 59.6 seconds
#
# 0: 384x640 15 persons, 26 cars, 12 motorcycles, 4 trucks, 57.6ms
# Speed: 2.7ms preprocess, 57.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 63.6 seconds
#
# 0: 384x640 16 persons, 23 cars, 14 motorcycles, 6 trucks, 53.8ms
# Speed: 2.9ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 64.4 seconds
#
# 0: 384x640 12 persons, 23 cars, 13 motorcycles, 5 trucks, 53.4ms
# Speed: 2.8ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 12 persons, 24 cars, 12 motorcycles, 5 trucks, 51.4ms
# Speed: 2.3ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.8 seconds
#
# 0: 384x640 9 persons, 24 cars, 9 motorcycles, 4 trucks, 59.1ms
# Speed: 2.8ms preprocess, 59.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 59.6 seconds
#
# 0: 384x640 8 persons, 24 cars, 11 motorcycles, 3 trucks, 53.4ms
# Speed: 2.3ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 10 persons, 24 cars, 10 motorcycles, 4 trucks, 52.1ms
# Speed: 2.5ms preprocess, 52.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 60.4 seconds
#
# 0: 384x640 12 persons, 24 cars, 12 motorcycles, 4 trucks, 53.0ms
# Speed: 2.6ms preprocess, 53.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Final allocated time for Signal 1: 62.0 seconds
#
# 0: 384x640 2 persons, 17 cars, 3 buss, 137.8ms
# Speed: 5.1ms preprocess, 137.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = incoming
# Signal 1 received update from Signal 2: Congestion = medium, Direction = incoming
# Signal 1 received from Signal 2: Congestion = medium, Direction = incoming, Message: "Don't increase the Signal Time beyond 50 seconds"
# Final allocated time for Signal 1: 40.0 seconds
#
# 0: 384x640 4 persons, 17 cars, 4 buss, 132.5ms
# Speed: 5.6ms preprocess, 132.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\chand\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1968, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\chand\AppData\Local\Temp\ipykernel_9924\4254705668.py", line 224, in start_processing
#     processor.process_video(file_path)
#   File "C:\Users\chand\AppData\Local\Temp\ipykernel_9924\4254705668.py", line 138, in process_video
#     signal_time = self.signal_controller.calculate_signal_time(vehicle_count)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\chand\AppData\Local\Temp\ipykernel_9924\4254705668.py", line 44, in calculate_signal_time
#     f"Congestion = {data['congestion']}, Direction = incoming, "
#                     ^^^^
# NameError: name 'data' is not defined
# 0: 384x640 2 persons, 17 cars, 3 buss, 98.0ms
# Speed: 3.4ms preprocess, 98.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = incoming
# Signal 1 received update from Signal 2: Congestion = medium, Direction = incoming
# Signal 1 received from Signal 2: Congestion = medium, Direction = incoming, Message: "Don't increase the Signal Time beyond 50 seconds"
# Final allocated time for Signal 1: 40.0 seconds
#
# 0: 384x640 4 persons, 17 cars, 4 buss, 89.4ms
# Speed: 3.8ms preprocess, 89.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\chand\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1968, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\chand\AppData\Local\Temp\ipykernel_9924\4254705668.py", line 224, in start_processing
#     processor.process_video(file_path)
#   File "C:\Users\chand\AppData\Local\Temp\ipykernel_9924\4254705668.py", line 138, in process_video
#     signal_time = self.signal_controller.calculate_signal_time(vehicle_count)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\chand\AppData\Local\Temp\ipykernel_9924\4254705668.py", line 44, in calculate_signal_time
#     f"Congestion = {data['congestion']}, Direction = incoming, "
#                     ^^^^
# NameError: name 'data' is not defined
