# %%
from ultralytics import YOLO
import cv2
import tkinter as tk
from tkinter import filedialog

# Load pre-trained YOLOv8 model
model = YOLO('yolov8n.pt')  # YOLOv8 Nano model (Fast & Lightweight)

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

# Dictionary to store vehicle counts for each lane
lane_vehicle_counts = {}

def calculate_signal_time(vehicle_count):
    if vehicle_count <= 5:
        time = 10  # Minimum signal time for <= 5 vehicles
    elif 6 <= vehicle_count <= 25:
        time = 10 + (vehicle_count - 5) * 2  # Linear adjustment between 10 and 50
    elif vehicle_count > 25:
        time = 50 + (vehicle_count - 25) * 0.8  # Increase from 50 up to max 70
    else:
        time = 50  # Default signal time for 25 vehicles
    
    return max(10, min(time, 70))  # Ensure time is between 10 and 70 seconds

def process_video(video_source):
    cap = cv2.VideoCapture(video_source)
    if not cap.isOpened():
        print(f"Error: Could not open video source {video_source}")
        return
    
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Failed to capture frame")
            break
        
        # Perform detection
        results = model(frame)
        result_frame = results[0].plot()  # Plot detection results on the frame
        
        # Counting Vehicles
        vehicle_count = 0
        for result in results:
            for box in result.boxes:
                cls = model.names[int(box.cls)]  # Class name
                if cls in vehicle_classes:
                    vehicle_count += 1
        
        # Display vehicle count and signal time on the frame
        signal_time = calculate_signal_time(vehicle_count)
        cv2.putText(result_frame, f"Vehicles: {vehicle_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        cv2.putText(result_frame, f"Signal Time: {signal_time}s", (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        # Display the result frame
        cv2.imshow("Real-Time Traffic Detection", result_frame)
        
        # Exit on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Release resources
    cap.release()
    cv2.destroyAllWindows()

def start_real_time_processing():
    video_source = 0  # Use 0 for webcam or provide a video file path
    process_video(video_source)

def upload_and_process_video():
    file_path = filedialog.askopenfilename(title="Select Video File", filetypes=[("Video Files", "*.mp4;*.avi;*.mov")])
    if not file_path:
        print("No video file selected")
        return
    process_video(file_path)

# Create GUI window
root = tk.Tk()
root.title("Traffic Vehicle Detection")
root.geometry("400x200")

# Button for real-time webcam processing
btn_webcam = tk.Button(root, text="Start Real-Time Webcam Processing", command=start_real_time_processing)
btn_webcam.pack(pady=10)

# Button for uploading and processing a video file
btn_upload = tk.Button(root, text="Upload and Process Video File", command=upload_and_process_video)
btn_upload.pack(pady=10)

root.mainloop()

# %%
from ultralytics import YOLO
import cv2
import tkinter as tk
from tkinter import filedialog

# Load pre-trained YOLOv8 model
model = YOLO('yolov8n.pt')  # YOLOv8 Nano model (Fast & Lightweight)

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

def calculate_signal_time(vehicle_count):
    if vehicle_count <= 5:
        time = 10  # Minimum signal time for <= 5 vehicles
    elif 6 <= vehicle_count <= 25:
        time = 10 + (vehicle_count - 5) * 2  # Linear adjustment between 10 and 50
    elif vehicle_count > 25:
        time = 50 + (vehicle_count - 25) * 0.8  # Increase from 50 up to max 70
    else:
        time = 50  # Default signal time for 25 vehicles
    
    return max(10, min(time, 70))  # Ensure time is between 10 and 70 seconds

def process_video(video_source):
    cap = cv2.VideoCapture(video_source)
    if not cap.isOpened():
        print(f"Error: Could not open video source {video_source}")
        return
    
    total_vehicle_count = 0  # Track total vehicles passed
    
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Processing complete.")
            break
        
        # Perform detection
        results = model(frame)
        result_frame = results[0].plot()  # Plot detection results on the frame
        
        # Counting Vehicles
        frame_vehicle_count = 0
        for result in results:
            for box in result.boxes:
                cls = model.names[int(box.cls)]  # Class name
                if cls in vehicle_classes:
                    frame_vehicle_count += 1
        
        total_vehicle_count += frame_vehicle_count
        
        # Display vehicle count on the frame
        cv2.putText(result_frame, f"Frame Vehicles: {frame_vehicle_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        cv2.putText(result_frame, f"Total Vehicles: {total_vehicle_count}", (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        # Display the result frame
        cv2.imshow("Traffic Vehicle Detection", result_frame)
        
        # Exit on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Calculate final signal timing
    final_signal_time = calculate_signal_time(total_vehicle_count)
    print(f"Total Vehicles Passed: {total_vehicle_count}")
    print(f"Predicted Signal Time: {final_signal_time} seconds")
    
    # Release resources
    cap.release()
    cv2.destroyAllWindows()

def start_real_time_processing():
    video_source = 0  # Use 0 for webcam or provide a video file path
    process_video(video_source)

def upload_and_process_video():
    file_path = filedialog.askopenfilename(title="Select Video File", filetypes=[("Video Files", "*.mp4;*.avi;*.mov")])
    if not file_path:
        print("No video file selected")
        return
    process_video(file_path)

# Create GUI window
root = tk.Tk()
root.title("Traffic Vehicle Detection")
root.geometry("400x200")

# Button for real-time webcam processing
btn_webcam = tk.Button(root, text="Start Real-Time Webcam Processing", command=start_real_time_processing)
btn_webcam.pack(pady=10)

# Button for uploading and processing a video file
btn_upload = tk.Button(root, text="Upload and Process Video File", command=upload_and_process_video)
btn_upload.pack(pady=10)

root.mainloop()

# %%
import cv2
import tkinter as tk
from tkinter import filedialog, messagebox  # Added messagebox import here
from ultralytics import YOLO
import time
import threading
import socket
import json
from queue import Queue

# %%
# Load pre-trained YOLOv8 model
model = YOLO('yolov8n.pt')  # YOLOv8 Nano model

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

class TrafficSignalController:
    def __init__(self, signal_id):
        self.signal_id = signal_id
        self.current_signal_time = 10
        self.max_time = 70
        self.min_time = 10
        self.neighbor_signals = {}
        self.message_queue = Queue()
        
        # Setup UDP communication
        self.communication_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        self.communication_socket.settimeout(0.1)
        self.communication_socket.bind(('localhost', 5000 + signal_id))
        
        # Start receiver thread
        self.receive_thread = threading.Thread(target=self.receive_updates)
        self.receive_thread.daemon = True
        self.receive_thread.start()
        
        # Start processor thread
        self.process_thread = threading.Thread(target=self.process_messages)
        self.process_thread.daemon = True
        self.process_thread.start()

    def calculate_signal_time(self, frame_vehicle_count):
        """Calculate signal time with consideration for neighboring signals"""
        # Base calculation
        if frame_vehicle_count <= 5:
            base_time = 10
        elif 6 <= frame_vehicle_count <= 25:
            base_time = 10 + (frame_vehicle_count - 5) * 2
        else:
            base_time = 50 + (frame_vehicle_count - 25) * 0.8
        
        # Adjust based on neighboring signals' status
        neighbor_adjustment = 0
        current_time = time.time()
        
        for signal_id, data in list(self.neighbor_signals.items()):
            # Remove stale entries (older than 5 seconds)
            if current_time - data['last_update'] > 5:
                self.neighbor_signals.pop(signal_id, None)
                continue
                
            if data['congestion'] == 'high' and data['direction'] == 'incoming':
                neighbor_adjustment += 5  # Increase time if neighbors are congested
            elif data['congestion'] == 'low' and data['direction'] == 'outgoing':
                neighbor_adjustment -= 2  # Decrease time if outgoing routes are clear
        
        final_time = max(self.min_time, min(base_time + neighbor_adjustment, self.max_time))
        return final_time

    def update_neighbor_status(self, signal_id, congestion, direction):
        """Update status of neighboring signals"""
        self.neighbor_signals[signal_id] = {
            'congestion': congestion,
            'direction': direction,
            'last_update': time.time()
        }

    def send_update(self, congestion, direction):
        """Send status update to all neighboring signals"""
        message = json.dumps({
            'sender_id': self.signal_id,
            'congestion': congestion,
            'direction': direction,
            'timestamp': time.time()
        })
        
        for neighbor_id in self.neighbor_signals.keys():
            try:
                self.communication_socket.sendto(message.encode(), ('localhost', 5000 + neighbor_id))
            except Exception as e:
                print(f"Error sending to signal {neighbor_id}: {e}")

    def receive_updates(self):
        """Thread to continuously receive updates from neighboring signals"""
        while True:
            try:
                data, addr = self.communication_socket.recvfrom(1024)
                self.message_queue.put(data)
            except socket.timeout:
                continue
            except Exception as e:
                print(f"Receive error: {e}")
                time.sleep(1)

    def process_messages(self):
        """Thread to process received messages"""
        while True:
            if not self.message_queue.empty():
                try:
                    data = self.message_queue.get()
                    message = json.loads(data.decode())
                    self.update_neighbor_status(
                        message['sender_id'],
                        message['congestion'],
                        message['direction']
                    )
                except Exception as e:
                    print(f"Error processing message: {e}")
            time.sleep(0.1)

class VideoProcessor:
    def __init__(self, signal_id):
        self.cap = None
        self.processing = False
        self.signal_controller = TrafficSignalController(signal_id)
        self.last_frame_details = {
            'frame_number': 0,
            'vehicle_count': 0,
            'signal_time': 10,
            'congestion_level': 'low'
        }
        self.congestion_thresholds = {
            'low': 10,
            'medium': 25,
            'high': 40
        }
        self.direction = 'outgoing'
        self.last_status_print = 0

    def get_congestion_level(self, count):
        if count < self.congestion_thresholds['low']:
            return 'low'
        elif count < self.congestion_thresholds['medium']:
            return 'medium'
        else:
            return 'high'

    def process_video(self, video_source, neighbor_ids=None):
        # Initialize neighbor signals
        if neighbor_ids:
            for neighbor_id in neighbor_ids:
                self.signal_controller.neighbor_signals[neighbor_id] = {
                    'congestion': 'unknown',
                    'direction': 'unknown',
                    'last_update': 0
                }
        
        self.cap = cv2.VideoCapture(video_source)
        if not self.cap.isOpened():
            messagebox.showerror("Error", f"Could not open video source {video_source}")
            return
        
        self.processing = True
        frame_number = 0
        last_update_time = 0
        
        while self.processing:
            ret, frame = self.cap.read()
            if not ret:
                print("Reached end of video.")
                break
            
            frame_number += 1
            
            # Perform detection
            results = model(frame)
            result_frame = results[0].plot()
            
            # Count vehicles in current frame
            frame_vehicle_count = 0
            for result in results:
                for box in result.boxes:
                    cls = model.names[int(box.cls)]
                    if cls in vehicle_classes:
                        frame_vehicle_count += 1
            
            # Determine congestion level
            congestion_level = self.get_congestion_level(frame_vehicle_count)
            
            # Calculate signal time with traffic management logic
            current_signal_time = self.signal_controller.calculate_signal_time(frame_vehicle_count)
            
            # Update last frame details
            self.last_frame_details = {
                'frame_number': frame_number,
                'vehicle_count': frame_vehicle_count,
                'signal_time': current_signal_time,
                'congestion_level': congestion_level
            }
            
            # Print neighbor status periodically
            if time.time() - self.last_status_print > 2:
                self.print_neighbor_status()
                self.last_status_print = time.time()
            
            # Send updates to neighboring signals
            if time.time() - last_update_time > 1:
                self.signal_controller.send_update(congestion_level, self.direction)
                last_update_time = time.time()
            
            # Display information
            self.display_info(result_frame, frame_number, frame_vehicle_count, current_signal_time, congestion_level)
            
            # Show the result frame
            cv2.imshow(f"Signal {self.signal_controller.signal_id} - Traffic Detection", result_frame)
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                self.stop_processing()
                break
        
        self.print_last_frame_details()
        self.cleanup()

    def print_neighbor_status(self):
        """Print current neighbor status"""
        current_time = time.time()
        print("\n=== Current Neighbor Status ===")
        print(f"Signal {self.signal_controller.signal_id} at {time.ctime(current_time)}")
        
        if not self.signal_controller.neighbor_signals:
            print("No neighbor information available")
            return
            
        for signal_id, data in self.signal_controller.neighbor_signals.items():
            age = current_time - data['last_update']
            status = "STALE" if age > 5 else "ACTIVE"
            print(f"Signal {signal_id}: {data['congestion']} congestion ({data['direction']}) [Age: {age:.1f}s, {status}]")

    def display_info(self, frame, frame_num, vehicle_count, signal_time, congestion):
        cv2.putText(frame, f"Signal {self.signal_controller.signal_id}", (10, 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"Frame: {frame_num}", (10, 70), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Vehicles: {vehicle_count}", (10, 110), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Signal Time: {signal_time:.1f}s", (10, 150), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        congestion_color = (0, 0, 255) if congestion == 'high' else (0, 255, 0) if congestion == 'medium' else (255, 255, 0)
        cv2.putText(frame, f"Congestion: {congestion}", (10, 190), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, congestion_color, 2)
        cv2.putText(frame, "Press 'q' to stop", (10, 230), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    def print_last_frame_details(self):
        print("\n=== Last Frame Analysis ===")
        print(f"Signal ID: {self.signal_controller.signal_id}")
        print(f"Frame Number: {self.last_frame_details['frame_number']}")
        print(f"Vehicle Count: {self.last_frame_details['vehicle_count']}")
        print(f"Congestion Level: {self.last_frame_details['congestion_level']}")
        print(f"Calculated Signal Time: {self.last_frame_details['signal_time']:.1f} seconds")
        
        self.print_neighbor_status()

    def stop_processing(self):
        self.processing = False

    def cleanup(self):
        if self.cap is not None:
            self.cap.release()
        cv2.destroyAllWindows()

def start_signal_system():
    root = tk.Tk()
    root.title("Traffic Signal Controller")
    root.geometry("400x300")
    
    def start_processing():
        try:
            signal_id = int(signal_id_entry.get())
            neighbors = neighbor_entry.get().strip()
            neighbor_ids = [int(n) for n in neighbors.split(',')] if neighbors else []
            
            processor = VideoProcessor(signal_id)
            
            if webcam_var.get():
                processor.process_video(0, neighbor_ids)
            else:
                file_path = filedialog.askopenfilename(
                    title="Select Video File", 
                    filetypes=[("Video Files", "*.mp4;*.avi;*.mov")]
                )
                if file_path:
                    processor.process_video(file_path, neighbor_ids)
        except ValueError:
            messagebox.showerror("Error", "Please enter valid signal IDs")
        except Exception as e:
            messagebox.showerror("Error", f"An error occurred: {str(e)}")
    
    # GUI Elements
    tk.Label(root, text="Traffic Signal Controller", font=('Arial', 14)).pack(pady=10)
    
    tk.Label(root, text="Signal ID:").pack()
    signal_id_entry = tk.Entry(root)
    signal_id_entry.pack()
    
    tk.Label(root, text="Neighbor Signal IDs (comma separated):").pack()
    neighbor_entry = tk.Entry(root)
    neighbor_entry.pack()
    
    webcam_var = tk.BooleanVar(value=True)
    tk.Checkbutton(root, text="Use Webcam", variable=webcam_var).pack(pady=5)
    
    tk.Button(root, text="Start Processing", command=start_processing).pack(pady=10)
    
    root.mainloop()

if __name__ == "__main__":
    start_signal_system()
# Out:
# 0: 384x640 6 cars, 176.0ms
# Speed: 11.1ms preprocess, 176.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 14:59:51 2025
# No neighbor information available
#
# 0: 384x640 5 cars, 86.2ms
# Speed: 5.4ms preprocess, 86.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 79.8ms
# Speed: 3.5ms preprocess, 79.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 84.3ms
# Speed: 3.8ms preprocess, 84.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 87.7ms
# Speed: 3.1ms preprocess, 87.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 76.9ms
# Speed: 3.6ms preprocess, 76.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 traffic light, 107.7ms
# Speed: 3.2ms preprocess, 107.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 2 trucks, 76.2ms
# Speed: 2.7ms preprocess, 76.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 82.1ms
# Speed: 3.5ms preprocess, 82.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 77.9ms
# Speed: 3.5ms preprocess, 77.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 bus, 1 truck, 70.7ms
# Speed: 3.6ms preprocess, 70.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 71.6ms
# Speed: 3.3ms preprocess, 71.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 73.8ms
# Speed: 4.0ms preprocess, 73.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 70.3ms
# Speed: 3.2ms preprocess, 70.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 72.5ms
# Speed: 3.8ms preprocess, 72.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 71.1ms
# Speed: 3.3ms preprocess, 71.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 68.9ms
# Speed: 2.9ms preprocess, 68.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 77.8ms
# Speed: 3.5ms preprocess, 77.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 14:59:53 2025
# No neighbor information available
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 1 traffic light, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 traffic light, 111.7ms
# Speed: 4.1ms preprocess, 111.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 traffic light, 69.2ms
# Speed: 3.5ms preprocess, 69.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 70.8ms
# Speed: 3.0ms preprocess, 70.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 68.5ms
# Speed: 2.9ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 68.6ms
# Speed: 3.3ms preprocess, 68.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 3 trucks, 76.5ms
# Speed: 4.0ms preprocess, 76.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 89.2ms
# Speed: 3.3ms preprocess, 89.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 bus, 2 trucks, 70.8ms
# Speed: 5.8ms preprocess, 70.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 buss, 2 trucks, 127.9ms
# Speed: 3.0ms preprocess, 127.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 2 trucks, 1 traffic light, 69.3ms
# Speed: 3.3ms preprocess, 69.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 69.1ms
# Speed: 4.1ms preprocess, 69.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 trucks, 81.4ms
# Speed: 3.1ms preprocess, 81.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 bus, 1 truck, 67.5ms
# Speed: 3.1ms preprocess, 67.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 2 trucks, 1 traffic light, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 truck, 1 traffic light, 71.0ms
# Speed: 4.8ms preprocess, 71.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 trucks, 1 traffic light, 74.2ms
# Speed: 3.3ms preprocess, 74.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 2 trucks, 68.9ms
# Speed: 3.2ms preprocess, 68.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 14:59:55 2025
# No neighbor information available
#
# 0: 384x640 4 persons, 7 cars, 1 motorcycle, 1 bus, 1 truck, 66.7ms
# Speed: 3.1ms preprocess, 66.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 1 bus, 2 trucks, 72.1ms
# Speed: 3.4ms preprocess, 72.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 68.6ms
# Speed: 3.4ms preprocess, 68.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 74.9ms
# Speed: 3.5ms preprocess, 74.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 truck, 1 traffic light, 69.6ms
# Speed: 3.0ms preprocess, 69.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 1 traffic light, 66.5ms
# Speed: 3.5ms preprocess, 66.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 65.6ms
# Speed: 3.5ms preprocess, 65.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 63.8ms
# Speed: 2.5ms preprocess, 63.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 trucks, 58.2ms
# Speed: 2.9ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 1 traffic light, 60.8ms
# Speed: 2.9ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 1 traffic light, 59.7ms
# Speed: 2.8ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 2 buss, 1 traffic light, 58.8ms
# Speed: 2.6ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 buss, 1 traffic light, 55.5ms
# Speed: 3.1ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 54.7ms
# Speed: 2.4ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 53.4ms
# Speed: 2.1ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 84.9ms
# Speed: 2.3ms preprocess, 84.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 2 trucks, 57.3ms
# Speed: 2.6ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 58.1ms
# Speed: 2.3ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 56.5ms
# Speed: 2.7ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 2 motorcycles, 63.4ms
# Speed: 2.6ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 53.5ms
# Speed: 2.5ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 1 bus, 61.6ms
# Speed: 2.6ms preprocess, 61.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 14:59:57 2025
# No neighbor information available
#
# 0: 384x640 2 persons, 6 cars, 1 truck, 58.4ms
# Speed: 2.6ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 60.9ms
# Speed: 2.9ms preprocess, 60.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 62.1ms
# Speed: 2.4ms preprocess, 62.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 64.4ms
# Speed: 3.1ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 62.4ms
# Speed: 2.3ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 truck, 60.8ms
# Speed: 3.4ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 56.6ms
# Speed: 2.4ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 truck, 58.5ms
# Speed: 2.3ms preprocess, 58.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 66.9ms
# Speed: 2.5ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 62.1ms
# Speed: 2.6ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 70.1ms
# Speed: 2.7ms preprocess, 70.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 trucks, 62.5ms
# Speed: 2.6ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 58.4ms
# Speed: 2.5ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 56.0ms
# Speed: 2.7ms preprocess, 56.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 61.0ms
# Speed: 2.4ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 62.2ms
# Speed: 2.4ms preprocess, 62.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 84.2ms
# Speed: 3.1ms preprocess, 84.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 62.8ms
# Speed: 2.8ms preprocess, 62.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 trucks, 70.4ms
# Speed: 3.4ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 trucks, 63.7ms
# Speed: 2.7ms preprocess, 63.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 63.8ms
# Speed: 2.9ms preprocess, 63.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 motorcycle, 1 truck, 58.1ms
# Speed: 2.6ms preprocess, 58.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 14:59:59 2025
# No neighbor information available
#
# 0: 384x640 4 persons, 9 cars, 1 motorcycle, 2 trucks, 60.2ms
# Speed: 2.4ms preprocess, 60.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 1 truck, 57.6ms
# Speed: 2.4ms preprocess, 57.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 1 truck, 63.3ms
# Speed: 2.9ms preprocess, 63.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 2 trucks, 60.3ms
# Speed: 2.3ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 2 trucks, 59.1ms
# Speed: 2.1ms preprocess, 59.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 2 trucks, 63.5ms
# Speed: 2.5ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 bus, 2 trucks, 56.3ms
# Speed: 2.4ms preprocess, 56.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 truck, 65.3ms
# Speed: 2.4ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 2 trucks, 64.2ms
# Speed: 2.4ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 1 truck, 63.3ms
# Speed: 2.9ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 66.3ms
# Speed: 2.4ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 61.1ms
# Speed: 2.1ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 truck, 63.4ms
# Speed: 3.8ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 truck, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 61.5ms
# Speed: 2.6ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 truck, 1 traffic light, 56.8ms
# Speed: 2.4ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 truck, 1 traffic light, 100.3ms
# Speed: 2.3ms preprocess, 100.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 58.5ms
# Speed: 2.6ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 59.1ms
# Speed: 2.4ms preprocess, 59.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 57.8ms
# Speed: 2.3ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 1 truck, 59.2ms
# Speed: 2.3ms preprocess, 59.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:01 2025
# No neighbor information available
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 61.9ms
# Speed: 3.1ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 1 traffic light, 60.2ms
# Speed: 2.7ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 59.1ms
# Speed: 2.3ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 64.1ms
# Speed: 2.2ms preprocess, 64.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 1 truck, 63.0ms
# Speed: 2.3ms preprocess, 63.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 60.8ms
# Speed: 2.4ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 61.3ms
# Speed: 2.4ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 53.4ms
# Speed: 2.5ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 truck, 55.7ms
# Speed: 2.6ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 cars, 1 motorcycle, 1 truck, 65.7ms
# Speed: 2.3ms preprocess, 65.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 cars, 1 motorcycle, 1 truck, 60.9ms
# Speed: 3.2ms preprocess, 60.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 cars, 1 motorcycle, 1 truck, 62.6ms
# Speed: 2.6ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 cars, 1 motorcycle, 1 truck, 1 traffic light, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 cars, 1 truck, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 cars, 1 truck, 61.4ms
# Speed: 3.2ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 72.8ms
# Speed: 5.1ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 cars, 1 truck, 62.1ms
# Speed: 2.9ms preprocess, 62.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 cars, 1 truck, 62.6ms
# Speed: 2.4ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 1 truck, 61.5ms
# Speed: 2.5ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 65.8ms
# Speed: 3.2ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 cars, 1 truck, 60.4ms
# Speed: 2.5ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:03 2025
# No neighbor information available
#
# 0: 384x640 6 persons, 8 cars, 1 truck, 59.7ms
# Speed: 2.3ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 1 truck, 57.7ms
# Speed: 2.4ms preprocess, 57.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 truck, 61.1ms
# Speed: 2.6ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 cars, 1 motorcycle, 1 truck, 55.1ms
# Speed: 2.7ms preprocess, 55.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 1 motorcycle, 1 truck, 1 traffic light, 59.9ms
# Speed: 2.2ms preprocess, 59.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 9 cars, 1 truck, 58.2ms
# Speed: 2.5ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 1 truck, 57.5ms
# Speed: 2.4ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 3 motorcycles, 1 truck, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 1 truck, 63.1ms
# Speed: 2.4ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 truck, 59.0ms
# Speed: 2.4ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 58.7ms
# Speed: 2.4ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 truck, 62.6ms
# Speed: 2.3ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 3 trucks, 59.7ms
# Speed: 2.3ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 3 trucks, 57.8ms
# Speed: 2.6ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 91.6ms
# Speed: 2.4ms preprocess, 91.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 2 trucks, 59.5ms
# Speed: 2.4ms preprocess, 59.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 59.0ms
# Speed: 2.4ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 2 trucks, 62.2ms
# Speed: 2.4ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 buss, 2 trucks, 64.8ms
# Speed: 3.1ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 buss, 2 trucks, 59.2ms
# Speed: 2.5ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 2 buss, 1 truck, 61.7ms
# Speed: 2.6ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 buss, 1 truck, 61.9ms
# Speed: 2.6ms preprocess, 61.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:05 2025
# No neighbor information available
#
# 0: 384x640 4 persons, 9 cars, 1 bus, 2 trucks, 63.0ms
# Speed: 2.4ms preprocess, 63.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 11 cars, 1 bus, 2 trucks, 73.5ms
# Speed: 2.9ms preprocess, 73.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 1 bus, 1 truck, 56.5ms
# Speed: 2.3ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 56.1ms
# Speed: 2.5ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 2 buss, 1 truck, 62.4ms
# Speed: 2.2ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 58.0ms
# Speed: 2.4ms preprocess, 58.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 buss, 1 truck, 62.6ms
# Speed: 2.4ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 truck, 60.0ms
# Speed: 2.5ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 57.9ms
# Speed: 2.9ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 64.8ms
# Speed: 2.6ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 63.8ms
# Speed: 2.2ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 trucks, 56.4ms
# Speed: 2.3ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 61.3ms
# Speed: 2.2ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 105.9ms
# Speed: 3.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 trucks, 1 traffic light, 62.6ms
# Speed: 2.5ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 1 traffic light, 59.5ms
# Speed: 2.4ms preprocess, 59.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 1 traffic light, 61.0ms
# Speed: 2.3ms preprocess, 61.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 traffic light, 63.9ms
# Speed: 2.9ms preprocess, 63.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 62.6ms
# Speed: 2.3ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 traffic light, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 1 traffic light, 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 motorcycle, 1 traffic light, 64.7ms
# Speed: 3.4ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:07 2025
# No neighbor information available
#
# 0: 384x640 4 persons, 9 cars, 1 traffic light, 62.7ms
# Speed: 2.8ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 58.7ms
# Speed: 2.7ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.1ms
# Speed: 2.6ms preprocess, 61.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 66.7ms
# Speed: 3.3ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 57.8ms
# Speed: 2.4ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 61.3ms
# Speed: 2.1ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.9ms
# Speed: 2.3ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 64.4ms
# Speed: 2.3ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 60.5ms
# Speed: 2.8ms preprocess, 60.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 60.5ms
# Speed: 2.6ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 handbag, 97.6ms
# Speed: 2.3ms preprocess, 97.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 65.1ms
# Speed: 3.6ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 62.6ms
# Speed: 2.2ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 63.3ms
# Speed: 2.7ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 64.3ms
# Speed: 2.5ms preprocess, 64.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 62.8ms
# Speed: 2.6ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 57.1ms
# Speed: 2.5ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 62.2ms
# Speed: 2.6ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 60.3ms
# Speed: 2.6ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 62.4ms
# Speed: 2.4ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 62.1ms
# Speed: 2.4ms preprocess, 62.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:09 2025
# No neighbor information available
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 63.9ms
# Speed: 2.3ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 54.8ms
# Speed: 2.4ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 63.7ms
# Speed: 2.4ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 57.7ms
# Speed: 2.5ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 63.3ms
# Speed: 2.3ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 56.1ms
# Speed: 2.4ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 1 traffic light, 60.6ms
# Speed: 2.6ms preprocess, 60.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 56.2ms
# Speed: 2.4ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 57.4ms
# Speed: 2.5ms preprocess, 57.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 55.3ms
# Speed: 2.6ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 63.8ms
# Speed: 2.2ms preprocess, 63.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 58.8ms
# Speed: 2.2ms preprocess, 58.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 63.2ms
# Speed: 2.3ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 traffic light, 60.0ms
# Speed: 2.9ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 58.1ms
# Speed: 2.2ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 buss, 1 traffic light, 59.8ms
# Speed: 2.6ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 63.2ms
# Speed: 2.3ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 64.2ms
# Speed: 2.4ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 63.1ms
# Speed: 2.4ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 69.5ms
# Speed: 2.4ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 2.7ms preprocess, 61.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 58.9ms
# Speed: 2.4ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:11 2025
# No neighbor information available
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 60.0ms
# Speed: 2.9ms preprocess, 60.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 61.1ms
# Speed: 2.4ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 1 truck, 56.6ms
# Speed: 2.5ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 57.1ms
# Speed: 3.6ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 1 truck, 86.3ms
# Speed: 5.3ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 61.1ms
# Speed: 2.5ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 2 buss, 62.6ms
# Speed: 2.4ms preprocess, 62.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 63.7ms
# Speed: 2.4ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 58.8ms
# Speed: 2.7ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 61.8ms
# Speed: 2.3ms preprocess, 61.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 63.0ms
# Speed: 3.6ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 59.0ms
# Speed: 2.7ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 59.3ms
# Speed: 2.4ms preprocess, 59.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 55.7ms
# Speed: 2.2ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 bus, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 56.8ms
# Speed: 2.6ms preprocess, 56.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 59.7ms
# Speed: 2.4ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 60.6ms
# Speed: 2.3ms preprocess, 60.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 62.1ms
# Speed: 2.4ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 57.1ms
# Speed: 2.3ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:13 2025
# No neighbor information available
#
# === Last Frame Analysis ===
# Signal ID: 1
# Frame Number: 236
# Vehicle Count: 4
# Congestion Level: low
# Calculated Signal Time: 10.0 seconds
#
# === Current Neighbor Status ===
# Signal 1 at Fri Mar 28 15:00:13 2025
# No neighbor information available

# %%
from tkinter import messagebox


# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # Automatically downloads if not present

# Vehicle classes to detect
vehicle_classes = ['car', 'truck', 'bus', 'bicycle', 'motorcycle']

class TrafficSignalController:
    def __init__(self, signal_id, neighbors=None):
        self.signal_id = signal_id
        self.current_signal_time = 10
        self.max_time = 70
        self.min_time = 10
        self.neighbor_signals = {}  # Stores neighbor congestion data
        self.congestion_level = "low"
        
        # Initialize neighbors (simulated)
        if neighbors:
            for neighbor_id in neighbors:
                self.neighbor_signals[neighbor_id] = {
                    'congestion': 'low',
                    'direction': 'outgoing',
                    'last_update': time.time()
                }

    def calculate_signal_time(self, frame_vehicle_count):
        """Adjust signal time based on vehicle count & neighbor congestion"""
        # Base calculation
        if frame_vehicle_count <= 5:
            base_time = 10
        elif 6 <= frame_vehicle_count <= 25:
            base_time = 10 + (frame_vehicle_count - 5) * 2
        else:
            base_time = 50 + (frame_vehicle_count - 25) * 0.8

        # Adjust based on neighbor congestion
        neighbor_adjustment = 0
        current_time = time.time()
        
        for neighbor_id, data in list(self.neighbor_signals.items()):
            # Remove stale entries (>5 sec old)
            if current_time - data['last_update'] > 5:
                continue
                
            if data['congestion'] == 'high' and data['direction'] == 'incoming':
                neighbor_adjustment += 5  # Increase time if neighbor is congested
            elif data['congestion'] == 'low' and data['direction'] == 'outgoing':
                neighbor_adjustment -= 2  # Decrease time if neighbor is clear

        final_time = max(self.min_time, min(base_time + neighbor_adjustment, self.max_time))
        return final_time

    def update_neighbor_status(self, neighbor_id, congestion, direction):
        """Update simulated neighbor's congestion status"""
        if neighbor_id in self.neighbor_signals:
            self.neighbor_signals[neighbor_id] = {
                'congestion': congestion,
                'direction': direction,
                'last_update': time.time()
            }
            # Print the received update
            print(f"Signal {neighbor_id} received update from Signal {self.signal_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")

    def send_congestion_update(self, congestion, direction):
        """Simulate sending congestion status to neighbors"""
        self.congestion_level = congestion
        for neighbor_id in self.neighbor_signals:
            # Print the status being sent before updating
            print(f"Signal {self.signal_id} sending to Signal {neighbor_id}: "
                  f"Congestion = {congestion}, Direction = {direction}")
            # Simulate neighbor receiving the update
            self.update_neighbor_status(neighbor_id, congestion, direction)

class VideoProcessor:
    def __init__(self, signal_id, neighbors=None):
        self.cap = None
        self.processing = False
        self.signal_controller = TrafficSignalController(signal_id, neighbors)
        self.last_frame_details = {
            'frame_number': 0,
            'vehicle_count': 0,
            'signal_time': 10,
            'congestion_level': 'low'
        }
        self.congestion_thresholds = {'low': 10, 'medium': 25, 'high': 40}
        self.direction = 'outgoing'  # Default traffic direction

    def get_congestion_level(self, count):
        if count < self.congestion_thresholds['low']:
            return 'low'
        elif count < self.congestion_thresholds['medium']:
            return 'medium'
        else:
            return 'high'

    def process_video(self, video_source):
        self.cap = cv2.VideoCapture(video_source)
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Could not open video source!")
            return

        self.processing = True
        frame_number = 0
        last_update_time = 0

        while self.processing:
            ret, frame = self.cap.read()
            if not ret:
                break

            frame_number += 1
            results = model(frame)
            result_frame = results[0].plot()

            # Count vehicles
            vehicle_count = sum(1 for result in results for box in result.boxes 
                              if model.names[int(box.cls)] in vehicle_classes)

            congestion = self.get_congestion_level(vehicle_count)
            signal_time = self.signal_controller.calculate_signal_time(vehicle_count)

            # Update last frame details
            self.last_frame_details = {
                'frame_number': frame_number,
                'vehicle_count': vehicle_count,
                'signal_time': signal_time,
                'congestion_level': congestion
            }

            # Send congestion updates (throttled to 1 per second)
            if time.time() - last_update_time > 1:
                print(f"\n--- Frame {frame_number} Update ---")
                print(f"Current congestion at Signal {self.signal_controller.signal_id}: {congestion}")
                self.signal_controller.send_congestion_update(congestion, self.direction)
                last_update_time = time.time()

            # Display info
            self.display_info(result_frame, frame_number, vehicle_count, signal_time, congestion)
            cv2.imshow(f"Signal {self.signal_controller.signal_id}", result_frame)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                self.stop_processing()

        self.cleanup()

    def display_info(self, frame, frame_num, vehicles, signal_time, congestion):
        cv2.putText(frame, f"Signal {self.signal_controller.signal_id}", (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"Vehicles: {vehicles}", (10, 70), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(frame, f"Signal Time: {signal_time:.1f}s", (10, 110), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        color = (0, 0, 255) if congestion == 'high' else (0, 255, 0) if congestion == 'medium' else (255, 255, 0)
        cv2.putText(frame, f"Congestion: {congestion}", (10, 150), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        cv2.putText(frame, "Press 'q' to stop", (10, 190), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    def stop_processing(self):
        self.processing = False

    def cleanup(self):
        if self.cap:
            self.cap.release()
        cv2.destroyAllWindows()

def start_signal_system():
    root = tk.Tk()
    root.title("Traffic Signal Controller")
    root.geometry("400x250")

    def start_processing():
        try:
            signal_id = int(signal_id_entry.get())
            neighbors = neighbor_entry.get().strip()
            neighbor_ids = [int(n) for n in neighbors.split(',')] if neighbors else []
            
            processor = VideoProcessor(signal_id, neighbor_ids)
            
            if webcam_var.get():
                processor.process_video(0)  # Webcam
            else:
                file_path = filedialog.askopenfilename(filetypes=[("Video Files", "*.mp4;*.avi")])
                if file_path:
                    processor.process_video(file_path)
        except ValueError:
            messagebox.showerror("Error", "Invalid signal/neighbor ID!")

    # GUI Layout
    tk.Label(root, text="Signal ID:").pack()
    signal_id_entry = tk.Entry(root)
    signal_id_entry.pack()

    tk.Label(root, text="Neighbor IDs (comma-separated):").pack()
    neighbor_entry = tk.Entry(root)
    neighbor_entry.pack()

    webcam_var = tk.BooleanVar(value=True)
    tk.Checkbutton(root, text="Use Webcam", variable=webcam_var).pack(pady=5)

    tk.Button(root, text="Start", command=start_processing).pack(pady=10)
    root.mainloop()

if __name__ == "__main__":
    start_signal_system()
# Out:
# 0: 384x640 6 cars, 116.5ms
# Speed: 6.4ms preprocess, 116.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 1 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 5 cars, 118.0ms
# Speed: 3.7ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 123.6ms
# Speed: 4.3ms preprocess, 123.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 111.0ms
# Speed: 5.1ms preprocess, 111.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 70.8ms
# Speed: 3.0ms preprocess, 70.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 71.8ms
# Speed: 3.2ms preprocess, 71.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 traffic light, 71.9ms
# Speed: 3.3ms preprocess, 71.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 2 trucks, 72.5ms
# Speed: 4.0ms preprocess, 72.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 70.2ms
# Speed: 2.9ms preprocess, 70.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 9 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 67.0ms
# Speed: 3.2ms preprocess, 67.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 bus, 1 truck, 66.7ms
# Speed: 2.9ms preprocess, 66.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 67.2ms
# Speed: 3.4ms preprocess, 67.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 69.5ms
# Speed: 2.8ms preprocess, 69.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 66.4ms
# Speed: 3.1ms preprocess, 66.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 70.6ms
# Speed: 3.1ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 67.6ms
# Speed: 3.4ms preprocess, 67.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 65.8ms
# Speed: 3.1ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 69.2ms
# Speed: 3.0ms preprocess, 69.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 1 traffic light, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 19 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 traffic light, 67.3ms
# Speed: 2.9ms preprocess, 67.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 traffic light, 92.6ms
# Speed: 3.2ms preprocess, 92.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 71.4ms
# Speed: 2.8ms preprocess, 71.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 69.9ms
# Speed: 3.5ms preprocess, 69.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 66.2ms
# Speed: 3.1ms preprocess, 66.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 3 trucks, 66.0ms
# Speed: 3.3ms preprocess, 66.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 65.2ms
# Speed: 3.0ms preprocess, 65.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 bus, 2 trucks, 68.1ms
# Speed: 3.2ms preprocess, 68.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 buss, 2 trucks, 68.2ms
# Speed: 3.8ms preprocess, 68.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 2 trucks, 1 traffic light, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 29 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 65.6ms
# Speed: 3.3ms preprocess, 65.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 trucks, 66.3ms
# Speed: 3.0ms preprocess, 66.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 bus, 1 truck, 78.5ms
# Speed: 3.8ms preprocess, 78.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 2 trucks, 1 traffic light, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 truck, 1 traffic light, 66.7ms
# Speed: 3.3ms preprocess, 66.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 trucks, 1 traffic light, 68.1ms
# Speed: 2.9ms preprocess, 68.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 2 trucks, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 motorcycle, 1 bus, 1 truck, 65.7ms
# Speed: 3.4ms preprocess, 65.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 1 bus, 2 trucks, 68.0ms
# Speed: 3.3ms preprocess, 68.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 67.2ms
# Speed: 3.5ms preprocess, 67.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 39 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 2 persons, 7 cars, 67.0ms
# Speed: 3.1ms preprocess, 67.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 truck, 1 traffic light, 70.1ms
# Speed: 2.9ms preprocess, 70.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 1 traffic light, 79.0ms
# Speed: 4.2ms preprocess, 79.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 70.1ms
# Speed: 3.4ms preprocess, 70.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 68.2ms
# Speed: 2.9ms preprocess, 68.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 trucks, 69.5ms
# Speed: 2.9ms preprocess, 69.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 1 traffic light, 69.1ms
# Speed: 3.6ms preprocess, 69.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 1 traffic light, 67.0ms
# Speed: 3.2ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 2 buss, 1 traffic light, 63.9ms
# Speed: 2.8ms preprocess, 63.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 buss, 1 traffic light, 65.5ms
# Speed: 3.3ms preprocess, 65.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 49 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 1 person, 6 cars, 1 bus, 66.9ms
# Speed: 2.8ms preprocess, 66.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 70.4ms
# Speed: 3.0ms preprocess, 70.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 65.9ms
# Speed: 3.8ms preprocess, 65.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 2 trucks, 67.0ms
# Speed: 3.4ms preprocess, 67.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 66.1ms
# Speed: 3.0ms preprocess, 66.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 66.9ms
# Speed: 2.8ms preprocess, 66.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 2 motorcycles, 67.0ms
# Speed: 2.7ms preprocess, 67.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 69.0ms
# Speed: 3.3ms preprocess, 69.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 1 bus, 70.9ms
# Speed: 3.1ms preprocess, 70.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 truck, 65.9ms
# Speed: 2.6ms preprocess, 65.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 59 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 66.5ms
# Speed: 2.9ms preprocess, 66.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 66.3ms
# Speed: 3.1ms preprocess, 66.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 68.4ms
# Speed: 3.0ms preprocess, 68.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 66.4ms
# Speed: 2.9ms preprocess, 66.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 truck, 94.2ms
# Speed: 7.5ms preprocess, 94.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 66.3ms
# Speed: 3.3ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 truck, 63.6ms
# Speed: 2.8ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 63.9ms
# Speed: 3.0ms preprocess, 63.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 62.2ms
# Speed: 3.3ms preprocess, 62.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 60.4ms
# Speed: 2.8ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 69 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 3 persons, 5 cars, 2 trucks, 60.6ms
# Speed: 2.6ms preprocess, 60.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 56.8ms
# Speed: 2.5ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 56.4ms
# Speed: 2.5ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 54.4ms
# Speed: 2.5ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 53.7ms
# Speed: 2.2ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 53.0ms
# Speed: 2.2ms preprocess, 53.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 trucks, 54.2ms
# Speed: 2.7ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 trucks, 51.7ms
# Speed: 3.5ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 56.9ms
# Speed: 3.1ms preprocess, 56.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 motorcycle, 1 truck, 55.8ms
# Speed: 2.2ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 motorcycle, 2 trucks, 55.0ms
# Speed: 2.5ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 81 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 6 persons, 8 cars, 1 truck, 55.7ms
# Speed: 2.4ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 1 truck, 56.9ms
# Speed: 2.3ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 2 trucks, 56.4ms
# Speed: 2.6ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 2 trucks, 55.7ms
# Speed: 3.2ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 2 trucks, 54.1ms
# Speed: 2.9ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 bus, 2 trucks, 54.3ms
# Speed: 2.2ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 truck, 55.8ms
# Speed: 2.3ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 2 trucks, 54.3ms
# Speed: 2.8ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 1 truck, 63.7ms
# Speed: 2.3ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 54.5ms
# Speed: 2.2ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 54.3ms
# Speed: 2.2ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 truck, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 93 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 6 persons, 4 cars, 1 truck, 54.9ms
# Speed: 2.4ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 53.1ms
# Speed: 3.3ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 truck, 1 traffic light, 52.5ms
# Speed: 2.4ms preprocess, 52.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 truck, 1 traffic light, 55.1ms
# Speed: 2.3ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 53.0ms
# Speed: 2.3ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 52.4ms
# Speed: 2.3ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 55.9ms
# Speed: 2.9ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 1 truck, 55.8ms
# Speed: 2.7ms preprocess, 55.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 55.3ms
# Speed: 3.7ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 54.1ms
# Speed: 2.9ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 1 traffic light, 53.4ms
# Speed: 3.1ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 1 traffic light, 53.5ms
# Speed: 2.5ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 55.5ms
# Speed: 2.4ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 106 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 4 persons, 3 cars, 1 truck, 53.4ms
# Speed: 3.3ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 54.5ms
# Speed: 2.4ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 truck, 93.4ms
# Speed: 2.5ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 58.0ms
# Speed: 2.4ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 truck, 55.1ms
# Speed: 3.3ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 cars, 1 motorcycle, 1 truck, 54.7ms
# Speed: 4.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 cars, 1 motorcycle, 1 truck, 55.1ms
# Speed: 2.4ms preprocess, 55.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 cars, 1 motorcycle, 1 truck, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 cars, 1 motorcycle, 1 truck, 1 traffic light, 56.5ms
# Speed: 2.6ms preprocess, 56.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 cars, 1 truck, 54.6ms
# Speed: 2.3ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 cars, 1 truck, 55.8ms
# Speed: 2.6ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 118 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 55.5ms
# Speed: 2.6ms preprocess, 55.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 cars, 1 truck, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 cars, 1 truck, 54.7ms
# Speed: 3.1ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 1 truck, 53.9ms
# Speed: 3.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 55.9ms
# Speed: 2.8ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 cars, 1 truck, 52.6ms
# Speed: 2.4ms preprocess, 52.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 1 truck, 56.2ms
# Speed: 2.9ms preprocess, 56.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 1 truck, 55.6ms
# Speed: 2.4ms preprocess, 55.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 truck, 54.1ms
# Speed: 2.5ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 cars, 1 motorcycle, 1 truck, 53.7ms
# Speed: 2.4ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 1 motorcycle, 1 truck, 1 traffic light, 53.3ms
# Speed: 2.2ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 9 cars, 1 truck, 58.6ms
# Speed: 2.6ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 130 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 9 persons, 8 cars, 1 truck, 52.9ms
# Speed: 2.4ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 3 motorcycles, 1 truck, 53.9ms
# Speed: 2.3ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 1 truck, 55.2ms
# Speed: 2.3ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 truck, 53.6ms
# Speed: 2.6ms preprocess, 53.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 55.5ms
# Speed: 2.3ms preprocess, 55.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 truck, 53.7ms
# Speed: 2.6ms preprocess, 53.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 3 trucks, 52.0ms
# Speed: 2.2ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 3 trucks, 55.1ms
# Speed: 2.5ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 54.1ms
# Speed: 2.2ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 2 trucks, 54.9ms
# Speed: 2.6ms preprocess, 54.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 54.3ms
# Speed: 2.3ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 2 trucks, 52.4ms
# Speed: 3.1ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 buss, 2 trucks, 88.7ms
# Speed: 4.3ms preprocess, 88.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 143 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 2 persons, 10 cars, 2 buss, 2 trucks, 53.2ms
# Speed: 2.3ms preprocess, 53.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 2 buss, 1 truck, 56.1ms
# Speed: 2.6ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 buss, 1 truck, 55.0ms
# Speed: 2.9ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 bus, 2 trucks, 60.7ms
# Speed: 2.8ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 11 cars, 1 bus, 2 trucks, 52.5ms
# Speed: 2.8ms preprocess, 52.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 1 bus, 1 truck, 54.5ms
# Speed: 2.6ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 2 buss, 1 truck, 55.2ms
# Speed: 2.8ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 56.2ms
# Speed: 2.6ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 buss, 1 truck, 53.9ms
# Speed: 2.5ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 truck, 53.0ms
# Speed: 2.4ms preprocess, 53.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 53.5ms
# Speed: 2.4ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 155 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 54.5ms
# Speed: 2.8ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 54.7ms
# Speed: 2.6ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 trucks, 64.0ms
# Speed: 2.8ms preprocess, 64.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 55.2ms
# Speed: 2.3ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 54.5ms
# Speed: 3.7ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 trucks, 1 traffic light, 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 1 traffic light, 54.3ms
# Speed: 2.5ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 1 traffic light, 55.1ms
# Speed: 2.4ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 traffic light, 52.4ms
# Speed: 2.1ms preprocess, 52.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 89.0ms
# Speed: 2.7ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 traffic light, 55.1ms
# Speed: 2.5ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 1 traffic light, 55.5ms
# Speed: 3.6ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 167 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 3 persons, 9 cars, 1 motorcycle, 1 traffic light, 55.0ms
# Speed: 2.8ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 traffic light, 52.9ms
# Speed: 2.3ms preprocess, 52.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 56.6ms
# Speed: 3.7ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 57.5ms
# Speed: 2.4ms preprocess, 57.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 54.7ms
# Speed: 3.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 55.6ms
# Speed: 2.5ms preprocess, 55.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 53.4ms
# Speed: 2.2ms preprocess, 53.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 54.7ms
# Speed: 2.6ms preprocess, 54.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 54.2ms
# Speed: 2.5ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 52.7ms
# Speed: 2.3ms preprocess, 52.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 handbag, 54.7ms
# Speed: 2.6ms preprocess, 54.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.3ms
# Speed: 2.8ms preprocess, 53.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 180 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 3 persons, 7 cars, 61.0ms
# Speed: 2.4ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 55.2ms
# Speed: 2.4ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 52.8ms
# Speed: 3.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 57.2ms
# Speed: 2.3ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 55.3ms
# Speed: 3.3ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 54.3ms
# Speed: 2.4ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 90.0ms
# Speed: 3.1ms preprocess, 90.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 55.6ms
# Speed: 2.6ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 53.2ms
# Speed: 2.5ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 54.5ms
# Speed: 2.7ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 55.5ms
# Speed: 2.5ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 54.3ms
# Speed: 2.4ms preprocess, 54.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 192 Update ---
# Current congestion at Signal 1: medium
# Signal 1 sending to Signal 2: Congestion = medium, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = medium, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = medium, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = medium, Direction = outgoing
#
# 0: 384x640 2 persons, 8 cars, 53.3ms
# Speed: 2.4ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 55.9ms
# Speed: 2.6ms preprocess, 55.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 56.0ms
# Speed: 2.6ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 53.5ms
# Speed: 2.5ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 1 traffic light, 54.7ms
# Speed: 2.4ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 53.3ms
# Speed: 2.5ms preprocess, 53.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.9ms
# Speed: 3.2ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 57.6ms
# Speed: 2.3ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 57.6ms
# Speed: 2.3ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 57.4ms
# Speed: 2.5ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 56.0ms
# Speed: 2.4ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 55.7ms
# Speed: 2.4ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 traffic light, 83.0ms
# Speed: 2.2ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 205 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 53.8ms
# Speed: 2.6ms preprocess, 53.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 buss, 1 traffic light, 59.6ms
# Speed: 3.3ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 55.4ms
# Speed: 2.6ms preprocess, 55.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 52.7ms
# Speed: 2.4ms preprocess, 52.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 55.9ms
# Speed: 3.2ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 54.7ms
# Speed: 2.8ms preprocess, 54.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 55.7ms
# Speed: 2.5ms preprocess, 55.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 54.2ms
# Speed: 3.1ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 56.7ms
# Speed: 2.3ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 57.7ms
# Speed: 2.4ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 1 truck, 55.7ms
# Speed: 2.9ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 54.0ms
# Speed: 2.4ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 1 truck, 57.7ms
# Speed: 2.5ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# --- Frame 218 Update ---
# Current congestion at Signal 1: low
# Signal 1 sending to Signal 2: Congestion = low, Direction = outgoing
# Signal 2 received update from Signal 1: Congestion = low, Direction = outgoing
# Signal 1 sending to Signal 3: Congestion = low, Direction = outgoing
# Signal 3 received update from Signal 1: Congestion = low, Direction = outgoing
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 2 buss, 54.2ms
# Speed: 2.3ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 bus, 54.3ms
# Speed: 2.5ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 52.7ms
# Speed: 2.9ms preprocess, 52.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 54.5ms
# Speed: 3.4ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
import time

class TrafficSignal:
    def __init__(self, signal_id):
        self.signal_id = signal_id
        self.current_green_time = 30  # Default time
        self.min_time = 10
        self.max_time = 60
        self.neighbors = {}  # Stores neighbor congestion data
        
    def update_neighbor_status(self, neighbor_id, congestion):
        """Receive updates from neighbors"""
        self.neighbors[neighbor_id] = {
            'congestion': congestion,
            'last_update': time.time()
        }
        print(f"Signal {self.signal_id} received update: {neighbor_id} has {congestion} congestion")
        
    def calculate_green_time(self, my_congestion):
        """Calculate new timing based on my status and neighbors"""
        base_time = self._get_base_time(my_congestion)
        adjustment = self._get_neighbor_adjustment()
        
        new_time = base_time + adjustment
        return max(self.min_time, min(new_time, self.max_time))
    
    def _get_base_time(self, congestion):
        """Base green time based on own congestion"""
        if congestion == "low":
            return 20
        elif congestion == "medium":
            return 35
        else:  # high
            return 50
    
    def _get_neighbor_adjustment(self):
        """Calculate time adjustment from neighbor status"""
        adjustment = 0
        current_time = time.time()
        
        # Remove stale data (older than 5 seconds)
        fresh_neighbors = {k:v for k,v in self.neighbors.items() 
                         if current_time - v['last_update'] <= 5}
        
        for neighbor_id, data in fresh_neighbors.items():
            if data['congestion'] == "high":
                adjustment += 5  # Help congested neighbor
            elif data['congestion'] == "low":
                adjustment -= 2  # Reduce time when neighbor is clear
                
        return adjustment

# Sample Usage
if __name__ == "__main__":
    # Create three connected signals
    signal1 = TrafficSignal(1)
    signal2 = TrafficSignal(2)
    signal3 = TrafficSignal(3)
    
    # Connect them as neighbors
    signal1.neighbors = {2: {'congestion': 'low', 'last_update': time.time()}}
    signal2.neighbors = {1: {'congestion': 'low', 'last_update': time.time()},
                        3: {'congestion': 'low', 'last_update': time.time()}}
    signal3.neighbors = {2: {'congestion': 'low', 'last_update': time.time()}}
    
    # Simulate traffic changes
    print("\n=== Initial State ===")
    print(f"Signal 1 time: {signal1.calculate_green_time('low')}s")
    print(f"Signal 2 time: {signal2.calculate_green_time('low')}s")
    print(f"Signal 3 time: {signal3.calculate_green_time('low')}s")
    
    # Signal 1 becomes congested
    print("\n=== Signal 1 becomes congested ===")
    signal2.update_neighbor_status(1, "high")  # Signal 1 reports congestion to Signal 2
    signal3.update_neighbor_status(2, "medium") # Signal 2 reports to Signal 3
    
    print("\n=== Adjusted Times ===")
    print(f"Signal 1 time: {signal1.calculate_green_time('high')}s (self congested)")
    print(f"Signal 2 time: {signal2.calculate_green_time('medium')}s (helping Signal 1)")
    print(f"Signal 3 time: {signal3.calculate_green_time('low')}s (normal operation)")
# Out:
# === Initial State ===
# Signal 1 time: 18s
# Signal 2 time: 16s
# Signal 3 time: 18s
#
# === Signal 1 becomes congested ===
# Signal 2 received update: 1 has high congestion
# Signal 3 received update: 2 has medium congestion
#
# === Adjusted Times ===
# Signal 1 time: 48s (self congested)
# Signal 2 time: 38s (helping Signal 1)
# Signal 3 time: 20s (normal operation)

# %%
import time

class TrafficSignal:
    def __init__(self, signal_id):
        self.signal_id = signal_id
        self.current_green_time = 30  # Default time
        self.min_time = 10
        self.max_time = 60
        self.neighbors = {}  # Stores neighbor congestion data
        
    def update_neighbor_status(self, neighbor_id, congestion):
        """Receive updates from neighbors"""
        self.neighbors[neighbor_id] = {
            'congestion': congestion,
            'last_update': time.time()
        }
        print(f"Signal {self.signal_id} received update: {neighbor_id} has {congestion} congestion")
        
    def calculate_green_time(self, my_congestion):
        """Calculate new timing based on my status and neighbors"""
        base_time = self._get_base_time(my_congestion)
        adjustment = self._get_neighbor_adjustment()
        
        new_time = base_time + adjustment
        return max(self.min_time, min(new_time, self.max_time))
    
    def _get_base_time(self, congestion):
        """Base green time based on own congestion"""
        if congestion == "low":
            return 20
        elif congestion == "medium":
            return 35
        else:  # high
            return 50
    
    def _get_neighbor_adjustment(self):
        """Calculate time adjustment from neighbor status"""
        adjustment = 0
        current_time = time.time()
        
        # Remove stale data (older than 5 seconds)
        fresh_neighbors = {k:v for k,v in self.neighbors.items() 
                         if current_time - v['last_update'] <= 5}
        
        for neighbor_id, data in fresh_neighbors.items():
            if data['congestion'] == "high":
                adjustment += 5  # Help congested neighbor
            elif data['congestion'] == "low":
                adjustment -= 2  # Reduce time when neighbor is clear
                
        return adjustment

# Sample Usage
if __name__ == "__main__":
    # Create three connected signals
    signal1 = TrafficSignal(1)
    signal2 = TrafficSignal(2)
    signal3 = TrafficSignal(3)
    
    # Connect them as neighbors
    signal1.neighbors = {2: {'congestion': 'low', 'last_update': time.time()}}
    signal2.neighbors = {1: {'congestion': 'low', 'last_update': time.time()},
                        3: {'congestion': 'low', 'last_update': time.time()}}
    signal3.neighbors = {2: {'congestion': 'low', 'last_update': time.time()}}
    
    # Simulate traffic changes
    print("\n=== Initial State ===")
    print(f"Signal 1 time: {signal1.calculate_green_time('low')}s")
    print(f"Signal 2 time: {signal2.calculate_green_time('low')}s")
    print(f"Signal 3 time: {signal3.calculate_green_time('low')}s")
    
    # Signal 1 becomes congested
    print("\n=== Signal 1 becomes congested ===")
    signal2.update_neighbor_status(1, "high")  # Signal 1 reports congestion to Signal 2
    signal3.update_neighbor_status(2, "medium") # Signal 2 reports to Signal 3
    
    print("\n=== Adjusted Times ===")
    print(f"Signal 1 time: {signal1.calculate_green_time('high')}s (self congested)")
    print(f"Signal 2 time: {signal2.calculate_green_time('medium')}s (helping Signal 1)")
    print(f"Signal 3 time: {signal3.calculate_green_time('low')}s (normal operation)")

# %% [markdown]
# ### How This Works:
#
# 1. **Each Signal Has:**
#    - Default min/max timing limits (10-60 seconds)
#    - Current green time duration
#    - List of neighbors and their last reported status
#
# 2. **Three Key Methods:**
#    - `update_neighbor_status()`: Receives congestion updates ("low/medium/high")
#    - `calculate_green_time()`: Determines new timing based on:
#      - Its own congestion level
#      - Neighbors' congestion levels
#    - Makes adjustments (+5s for helping congested neighbors, -2s when neighbors are clear)
#
# 3. **Sample Simulation Shows:**
#    - Initial state: All signals at normal timing
#    - When Signal 1 becomes congested:
#      - Signal 2 increases its time to help (35 → ~40s)
#      - Signal 3 makes minor adjustment based on Signal 2's status
#    - All signals stay within safe limits
#
# ### Key Logic:
# ```python
# if neighbor == "high":
#     my_time += 5  # Help congested neighbor
# elif neighbor == "low":
#     my_time -= 2  # Reduce time when neighbor is clear
# ```
#
# This demonstrates the core coordination logic where signals automatically adjust to help each other based on real-time congestion updates.
